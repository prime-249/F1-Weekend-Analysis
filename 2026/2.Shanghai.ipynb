# %%
import pandas as pd
from Main import Session

# %% [markdown]
# # Shootout Qualifying

# %%
sq = Session('Shanghai', 'SQ', 2026)
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Sprint Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# core        WARNING 	Sprint Qualifying is not supported by Ergast! Limited results are calculated from timing data.
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# --------------- Deciding where to store cache...
# --------------- Cache folder identified.
# --------------- Polling and loading session data...
# core        WARNING 	No lap data for driver 11
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 11)
# ...

# %%
sq.chart_ideal_lap()
# Out:
# /Users/dario/Documents/Python Stuff/F1-Weekend-Analysis/2026/Main.py:304: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   improv_df = pd.concat([improv_df,pd.DataFrame(ideal,columns=improv_df.columns,index=[i])])
# --------------- Generating Delta from Pole chart...

# %%
sq.chart_delta_from_pole()
# Out:
# --------------- Generating Delta from Pole chart...
# /Users/dario/Documents/Python Stuff/F1-Weekend-Analysis/2026/Main.py:367: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(custom_y_ticks_labels)

# %% [markdown]
# # Sprint Race

# %%
sr = Session('Shanghai', 'Sprint', 2026)
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Sprint [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# --------------- Deciding where to store cache...
# --------------- Cache folder identified.
# --------------- Polling and loading session data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# logger      WARNING 	Failed to load telemetry data!
# req            INFO 	Using cached data for weather_data
# ...

# %%
sr.chart_stint_comparison('RUS')
# Out:
# --------------- Generating Stints comparison chart...

# %%
sr.chart_race_pace_comparison(('HAM','RUS'))
# Out:
# --------------- Generating race pace comparison between ('HAM', 'RUS')

# %%
sr.chart_race_pace_comparison(('ANT','VER'))
# Out:
# --------------- Generating race pace comparison between ('ANT', 'VER')

# %%
sr.chart_top_speed_comparison()
# Out:
# /Users/dario/Documents/Python Stuff/F1-Weekend-Analysis/2026/Main.py:254: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=self.df.groupby('Driver')['SpeedST'].max().sort_values(ascending=False),
# --------------- Top speed comparison chart generated.

# %%
sr.chart_delta_from_pole() # Expecting a TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sr.chart_delta_from_pole()
#
# File ~/Documents/Python Stuff/F1-Weekend-Analysis/2026/Main.py:340, in Session.chart_delta_from_pole(self)
#     336 """
#     337 Generates chart showing delta from pole for drivers who made it into the last quali session
#     338 """
#     339 if self.session.upper() not in ['Q','SQ']:
# --> 340     raise TypeError('Please load a race session for this functionality.')
#     341 else:
#     342     print('-'*15,'Generating Delta from Pole chart...')
#
# TypeError: Please load a race session for this functionality.
