# %% [markdown]
# # Libraries

# %%
import pandas as pd
from Main import Session

# %% [markdown]
# # Race

# %%
aus_race = Session(grand_prix='Australia', session='R', year=2026)
aus_race.chart_race_pace()
# Out:
# --------------- Deciding where to store cache...
# --------------- Cache folder identified.
# --------------- Polling and loading session data...
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 81
# ...

# %%
aus_race.chart_race_pace()
# Out:
# --------------- Generating Race Pace chart...
# /Users/dario/Documents/Python Stuff/F1/2026/Main.py:187: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='upper right')
# --------------- Race Pace chart generated.

# %%
help(aus_race.chart_race_pace_comparison)
# Out:
# Help on method chart_race_pace_comparison in module Main:
#
# chart_race_pace_comparison(drivers: tuple) method of Main.Session instance
#     Generates a race pace comparison chart between two drivers.
#     Only green-flag laps will be stored, while each driver's pitting lap(s) will be skipped for that driver only.
#
#     Args:
#         drivers (tuple): Tuple containing the two driver aliases, e.g. ('RUS','LEC')

# %%
aus_race.chart_race_pace_comparison(('VER','NOR'))
# Out:
# --------------- Generating race pace comparison between ('VER', 'NOR')

# %%
aus_race.chart_race_pace_comparison(('RUS','PER'))
# Out:
# --------------- Generating race pace comparison between ('RUS', 'PER')

# %%
aus_race.chart_top_speed_comparison()
# Out:
# /Users/dario/Documents/Python Stuff/F1/2026/Main.py:245: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=self.df.groupby('Driver')['SpeedST'].max().sort_values(ascending=False),
# --------------- Top speed comparison chart generated.

# %%
df = aus_race.df

# %%
df[(df['Driver']=='HAM') & (df['SpeedST']>315)]
# Out:
#                       Time Driver DriverNumber  LapTime  LapNumber  Stint  \
# 745 0 days 02:17:26.929000    HAM           44   83.008       52.0    2.0
# 748 0 days 02:21:35.071000    HAM           44   82.423       55.0    2.0
#
#     PitOutTime PitInTime  Sector1Time  Sector2Time  ...     Team  \
# 745        NaT       NaT       29.158       17.670  ...  Ferrari
# 748        NaT       NaT       29.094       17.613  ...  Ferrari
#
#               LapStartTime LapStartDate TrackStatus  Position  Deleted  \
# 745 0 days 02:16:03.921000          NaT           1       4.0    False
# 748 0 days 02:20:12.648000          NaT           1       4.0    False
#
#      DeletedReason  FastF1Generated IsAccurate PitLap
# 745                           False       True      0
# 748                           False       True      0
#
# [2 rows x 32 columns]

# %%
df[(df['Driver']=='LEC') & (df['SpeedST']>303)]
# Out:
#                       Time Driver DriverNumber  LapTime  LapNumber  Stint  \
# 301 0 days 02:17:24.035000    LEC           16   83.049       52.0    2.0
# 302 0 days 02:18:47.049000    LEC           16   83.014       53.0    2.0
#
#     PitOutTime PitInTime  Sector1Time  Sector2Time  ...     Team  \
# 301        NaT       NaT       29.441       17.598  ...  Ferrari
# 302        NaT       NaT       29.254       17.635  ...  Ferrari
#
#               LapStartTime LapStartDate TrackStatus  Position  Deleted  \
# 301 0 days 02:16:00.986000          NaT           1       3.0    False
# 302 0 days 02:17:24.035000          NaT           1       3.0    False
#
#      DeletedReason  FastF1Generated IsAccurate PitLap
# 301                           False       True      0
# 302                           False       True      0
#
# [2 rows x 32 columns]
