# %% [markdown]
# # Preliminary (libraries, cache, functions, color palettes)

# %%
import pandas as pd 
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-notebook')
import fastf1
from fastf1.core import Laps
import os
import seaborn as sns
import numpy as np

# %%
#Generating cache folder
cache_folder = 'cache_folder'
if not os.path.exists(cache_folder):
    os.makedirs(cache_folder)

fastf1.Cache.enable_cache(cache_folder)

# %%
def GetGapsInRace(session_laps):
    '''
    Generate new column containing the gap from the driver in front at the start of the lap
    Use it like this:
        - Get fastf1 session object
        - extract session.laps attribute (it is a df)
        - generate a new df with this funciont as new_df = GetGapsInRace(mysession.laps)
    '''
    #Empty gaps list
    gaps = []
    #Sort dataset so that we can iterate and directly identify drivers in front
    sorted_session_laps = session_laps.sort_values(['LapNumber','Position'])
    #iterate through dataset
    for row in range(0,sorted_session_laps.shape[0],1):
        #create specific lap object
        lap = sorted_session_laps.iloc[row]
        #check position existance
        if lap.Position:
            #avoid using lap 1, for obvious reasons
            if lap.LapNumber!=1:
                #skip position 1, their gap is always 0.000
                if lap.Position!=1:
                    print('\n\n',lap.LapNumber)
                    print(lap.LapStartTime,'laptime',lap.Driver,lap.LapNumber,'#')
                    print(sorted_session_laps.iloc[row-1]['LapStartTime'],'previous laptime',sorted_session_laps.iloc[row-1]['Driver'],sorted_session_laps.iloc[row-1]['LapNumber'])
                    gap_timedelta = lap.LapStartTime - sorted_session_laps.iloc[row-1]['LapStartTime']
                    print(gap_timedelta)
                    gap_seconds = gap_timedelta.total_seconds()
                    print(gap_seconds)
                    gaps.append(gap_seconds)
                else:
                    #add gap for position 1
                    print('adding gap 0 for first position')
                    gaps.append(float(0.000))
            else:
                print('lap 1 is skipped')
                gaps.append(float(0.000))
        else:
            print('position not found')
            gaps.append(np.NaN)
    sorted_session_laps['GapInSeconds'] = gaps
    return sorted_session_laps

# %%
#Extract season2025 events list 
#just for reference, not used later
season2025 = fastf1.get_event_schedule(2025)
season2025.head(6)
# Out:
#    RoundNumber       Country   Location  \
# 0            0       Bahrain     Sakhir
# 1            1     Australia  Melbourne
# 2            2         China   Shanghai
# 3            3         Japan     Suzuka
# 4            4       Bahrain     Sakhir
# 5            5  Saudi Arabia     Jeddah
#
#                                    OfficialEventName  EventDate  \
# 0           FORMULA 1 ARAMCO PRE-SEASON TESTING 2025 2025-02-28
# 1  FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ... 2025-03-16
# 2         FORMULA 1 HEINEKEN CHINESE GRAND PRIX 2025 2025-03-23
# 3         FORMULA 1 LENOVO JAPANESE GRAND PRIX 2025  2025-04-06
# 4         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2025 2025-04-13
# 5        FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2025 2025-04-20
#
#                   EventName        EventFormat    Session1  \
# 0        Pre-Season Testing            testing  Practice 1
# 1     Australian Grand Prix       conventional  Practice 1
# 2        Chinese Grand Prix  sprint_qualifying  Practice 1
# 3       Japanese Grand Prix       conventional  Practice 1
# 4        Bahrain Grand Prix       conventional  Practice 1
# 5  Saudi Arabian Grand Prix       conventional  Practice 1
#
#                 Session1Date     Session1DateUtc  ...    Session3  \
# 0  2025-02-26 10:00:00+03:00 2025-02-26 07:00:00  ...  Practice 3
# 1  2025-03-14 12:30:00+11:00 2025-03-14 01:30:00  ...  Practice 3
# 2  2025-03-21 11:30:00+08:00 2025-03-21 03:30:00  ...      Sprint
# 3  2025-04-04 11:30:00+09:00 2025-04-04 02:30:00  ...  Practice 3
# 4  2025-04-11 14:30:00+03:00 2025-04-11 11:30:00  ...  Practice 3
# 5  2025-04-18 16:30:00+03:00 2025-04-18 13:30:00  ...  Practice 3
#
#                 Session3Date     Session3DateUtc    Session4  \
# 0  2025-02-28 10:00:00+03:00 2025-02-28 07:00:00        None
# 1  2025-03-15 12:30:00+11:00 2025-03-15 01:30:00  Qualifying
# 2  2025-03-22 11:00:00+08:00 2025-03-22 03:00:00  Qualifying
# 3  2025-04-05 11:30:00+09:00 2025-04-05 02:30:00  Qualifying
# 4  2025-04-12 15:30:00+03:00 2025-04-12 12:30:00  Qualifying
# 5  2025-04-19 16:30:00+03:00 2025-04-19 13:30:00  Qualifying
#
#                 Session4Date     Session4DateUtc Session5  \
# 0                        NaT                 NaT     None
# 1  2025-03-15 16:00:00+11:00 2025-03-15 05:00:00     Race
# 2  2025-03-22 15:00:00+08:00 2025-03-22 07:00:00     Race
# 3  2025-04-05 15:00:00+09:00 2025-04-05 06:00:00     Race
# 4  2025-04-12 19:00:00+03:00 2025-04-12 16:00:00     Race
# 5  2025-04-19 20:00:00+03:00 2025-04-19 17:00:00     Race
#
#                 Session5Date     Session5DateUtc F1ApiSupport
# 0                        NaT                 NaT         True
# 1  2025-03-16 15:00:00+11:00 2025-03-16 04:00:00         True
# 2  2025-03-23 15:00:00+08:00 2025-03-23 07:00:00         True
# 3  2025-04-06 14:00:00+09:00 2025-04-06 05:00:00         True
# 4  2025-04-13 18:00:00+03:00 2025-04-13 15:00:00         True
# 5  2025-04-20 20:00:00+03:00 2025-04-20 17:00:00         True
#
# [6 rows x 23 columns]

# %%
team_colors = {
    "Alpine": "#F282B4",       # Pink
    "Aston Martin": "#037A68", # Green
    "Ferrari": "#821729",      # Burgundy
    "Haas F1 Team": "#EB0A1E",         # Red
    "Kick Sauber": "#53FC18",  # Bright Green
    "McLaren": "#FF8700",      # Papaya Orange
    "Mercedes": "#C8CCCE",     # Silver/Gray
    "Racing Bulls": "#FFFFFF", # White
    "Red Bull Racing": "#003773",     # Navy Blue
    "Williams": "#00A0DE",     # Blue
}
driver_colors = {
    # Red Bull Racing
    "VER": "#002D5A",  # Max Verstappen (Deep Navy Blue)
    "LAW": "#003F7D",  # Liam Lawson (Brighter Blue)

    # Ferrari
    "LEC": "#9B1B30",  # Charles Leclerc (Darker Burgundy)
    "HAM": "#C81D37",  # Lewis Hamilton (Brighter Red)

    # Mercedes
    "RUS": "#ACB2B5",  # George Russell (Dark Silver)
    "ANT": "#D0D3D4",  # Andrea Kimi Antonelli (Lighter Silver)

    # McLaren
    "NOR": "#FF9800",  # Lando Norris (Papaya Orange)
    "PIA": "#FFB766",  # Oscar Piastri (Lighter Papaya)

    # Aston Martin
    "ALO": "#028061",  # Fernando Alonso (Dark Green)
    "STR": "#03A678",  # Lance Stroll (Lighter Green)

    # Alpine
    "GAS": "#FF66A1",  # Pierre Gasly (Light Pink)
    "DOO": "#D94A90",  # Jack Doohan (Darker Pink)

    # Williams
    "ALB": "#0096C9",  # Alexander Albon (Deep Blue)
    "SAI": "#00B6F1",  # Carlos Sainz (Sky Blue)

    # Racing Bulls
    "HAD": "#E5E5E5",  # Isack Hadjar (Light Gray)
    "TSU": "#FFFFFF",  # Yuki Tsunoda (White)

    # Kick Sauber
    "HUL": "#4EF535",  # Nico Hülkenberg (Bright Green)
    "BOR": "#26D401",  # Gabriel Bortoleto (Darker Green)

    # Haas
    "OCO": "#D91A26",  # Esteban Ocon (Dark Red)
    "BEA": "#F52439",  # Oliver Bearman (Brighter Red)
}

# %% [markdown]
# # China FP1

# %%
#Extract China Free Practice 1 Data
china_fp1 = fastf1.get_session(2025,'China','FP1')
china_fp1.load()
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Practice 1 [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '5', '6', '7', '10', '12', '14', '16', '18', '22', '23', '27', '30', '31', '44', '55', '63', '81', '87']

# %%
#Generate dataframe from .laps attribute
china_fp1_df = china_fp1.laps

# %%
print(china_fp1_df.shape)
#Filter out deleted lap times
china_fp1_df = china_fp1_df[china_fp1_df['Deleted']!=True]
print(china_fp1_df.shape)
#Get only fresh_tyre stints
china_fp1_df = china_fp1_df[china_fp1_df['FreshTyre']==True]
print(china_fp1_df.shape)
# Out:
# (459, 31)
# (459, 31)
# (252, 31)

# %%
china_fp1_df.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
#Extract only useful variables
china_fp1_df = china_fp1.laps[['Team','Driver','DriverNumber','Compound','LapTime','LapNumber','SpeedST','Stint']]
#Delete occurrences where LapTime has not been recorded
china_fp1_df = china_fp1_df[china_fp1_df['LapTime'].isnull()!=True]
china_fp1_df.sample(10)
# Out:
#                 Team Driver DriverNumber Compound                LapTime  \
# 159         Mercedes    ANT           12   MEDIUM 0 days 00:02:23.898000
# 138         Mercedes    ANT           12   MEDIUM 0 days 00:02:23.941000
# 29           McLaren    NOR            4   MEDIUM 0 days 00:02:01.125000
# 44           McLaren    NOR            4     SOFT 0 days 00:01:31.504000
# 299  Red Bull Racing    LAW           30   MEDIUM 0 days 00:02:08.463000
# 59       Kick Sauber    BOR            5   MEDIUM 0 days 00:01:38.501000
# 395         Mercedes    RUS           63   MEDIUM 0 days 00:02:02.453000
# 424          McLaren    PIA           81   MEDIUM 0 days 00:01:36.485000
# 66       Kick Sauber    BOR            5     SOFT 0 days 00:01:34.077000
# 174     Aston Martin    ALO           14   MEDIUM 0 days 00:01:38.801000
#
#      LapNumber  SpeedST  Stint
# 159       26.0    219.0    4.0
# 138        5.0    202.0    1.0
# 29         6.0    204.0    1.0
# 44        21.0    331.0    3.0
# 299        8.0    251.0    1.0
# 59        13.0    313.0    2.0
# 395       10.0    279.0    1.0
# 424       13.0    311.0    2.0
# 66        20.0    332.0    3.0
# 174       14.0    315.0    3.0

# %%
#Extract Lap Time in total seconds (e.g.: 1:35.700 => 95.700)
china_fp1_df['LapTimeInSeconds'] = china_fp1_df['LapTime'].dt.total_seconds()
china_fp1_df.sample(10)
# Out:
# /var/folders/88/94pqx5n57z5crmg3w50s99y00000gn/T/ipykernel_2018/1386891660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   china_fp1_df['LapTimeInSeconds'] = china_fp1_df['LapTime'].dt.total_seconds()
#              Team Driver DriverNumber Compound                LapTime  \
# 402      Mercedes    RUS           63   MEDIUM 0 days 00:01:37.253000
# 419       McLaren    PIA           81   MEDIUM 0 days 00:01:53.547000
# 279   Kick Sauber    HUL           27   MEDIUM 0 days 00:01:34.207000
# 136      Mercedes    ANT           12   MEDIUM 0 days 00:01:36.268000
# 153      Mercedes    ANT           12   MEDIUM 0 days 00:01:38.866000
# 204       Ferrari    LEC           16     SOFT 0 days 00:02:16.558000
# 27        McLaren    NOR            4   MEDIUM 0 days 00:01:33.362000
# 252      Williams    ALB           23   MEDIUM 0 days 00:02:22.692000
# 244  Racing Bulls    TSU           22     SOFT 0 days 00:02:29.089000
# 34        McLaren    NOR            4   MEDIUM 0 days 00:01:44.615000
#
#      LapNumber  SpeedST  Stint  LapTimeInSeconds
# 402       17.0    318.0    2.0            97.253
# 419        8.0    313.0    1.0           113.547
# 279        9.0    332.0    2.0            94.207
# 136        3.0    331.0    1.0            96.268
# 153       20.0    315.0    2.0            98.866
# 204       21.0    329.0    3.0           136.558
# 27         4.0    326.0    1.0            93.362
# 252        6.0    171.0    1.0           142.692
# 244       21.0    189.0    3.0           149.089
# 34        11.0    310.0    2.0           104.615

# %%
china_fp1_df['Driver'].value_counts()
# Out:
# Driver
# ANT    22
# SAI    20
# VER    19
# LAW    19
# BEA    19
# RUS    19
# NOR    18
# ALB    18
# HUL    17
# GAS    17
# ALO    17
# BOR    16
# HAD    16
# PIA    16
# TSU    16
# OCO    15
# STR    14
# LEC    13
# HAM    12
# DOO    11
# Name: count, dtype: int64

# %% [markdown]
# <h3> Analyze stints lap times

# %%
ver_stints = china_fp1_df[(china_fp1_df['Driver']=='VER')]
ver_stints =  ver_stints[['Stint','LapTimeInSeconds']]
ver_stints
# Out:
#     Stint  LapTimeInSeconds
# 1     1.0            95.383
# 3     1.0            93.949
# 4     1.0           140.215
# 5     1.0           135.346
# 6     1.0            93.284
# 7     1.0           116.357
# 9     2.0            97.853
# 10    2.0            97.756
# 11    2.0            97.325
# 12    2.0            98.370
# 13    2.0            97.942
# 14    2.0            98.266
# 15    2.0            99.089
# 16    2.0            99.746
# 17    2.0            99.763
# 18    2.0           113.315
# 20    3.0            97.820
# 21    4.0           147.193
# 22    4.0           134.127

# %%
sns.boxplot(data=ver_stints,x='Stint',y='LapTimeInSeconds')
# Out:
# <Axes: xlabel='Stint', ylabel='LapTimeInSeconds'>

# %%
aka_stints = china_fp1_df[(china_fp1_df['Driver']=='ANT')]
aka_stints =  aka_stints[['Stint','LapTimeInSeconds']]
aka_stints
# Out:
#      Stint  LapTimeInSeconds
# 135    1.0           100.647
# 136    1.0            96.268
# 137    1.0            95.572
# 138    1.0           143.941
# 139    1.0            94.193
# 140    1.0           148.299
# 141    1.0            93.219
# 142    1.0           128.369
# 144    2.0            96.229
# 145    2.0            96.511
# 146    2.0            96.798
# 147    2.0            97.056
# 148    2.0            96.960
# 149    2.0            96.761
# 150    2.0            97.174
# 151    2.0            97.480
# 152    2.0            98.586
# 153    2.0            98.866
# 154    2.0           108.480
# 156    3.0            92.874
# 157    3.0           130.638
# 159    4.0           143.898

# %%
sns.boxplot(data=aka_stints,x='Stint',y='LapTimeInSeconds')
# Out:
# <Axes: xlabel='Stint', ylabel='LapTimeInSeconds'>

# %% [markdown]
# # China Sprint

# %%
#Extract china sprint data
china_sprint = fastf1.get_session(2025,'China','Sprint')
china_sprint.load()
print('China Sprint data loaded')
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Sprint [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 44 completed the race distance 00:00.020000 before the recorded end of the session.
# core           INFO 	Finished loading data for 20 drivers: ['44', '81', '1', '63', '16', '22', '12', '4', '18', '14', '23', '10', '6', '30', '87', '31', '55', '5', '27', '7']
# China Sprint data loaded

# %% [markdown]
# <h3> Find gaps between drivers per lap

# %%
#Apply function to get finalized dataframe
sorted_china_sprint = GetGapsInRace(china_sprint.laps)
sorted_china_sprint.head(10)
# Out:
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# lap 1 is skipped
# adding gap 0 for first position
#
#
#  2.0
# 0 days 00:46:51.118000 laptime VER 2.0 #
# 0 days 00:46:50.347000 previous laptime HAM 2.0
# 0 days 00:00:00.771000
# 0.771
#
#
#  2.0
# 0 days 00:46:52.437000 laptime PIA 2.0 #
# 0 days 00:46:51.118000 previous laptime VER 2.0
# 0 days 00:00:01.319000
# 1.319
#
#
#  2.0
# 0 days 00:46:53.660000 laptime RUS 2.0 #
# 0 days 00:46:52.437000 previous laptime PIA 2.0
# 0 days 00:00:01.223000
# 1.223
#
#
#  2.0
# 0 days 00:46:54.007000 laptime LEC 2.0 #
# 0 days 00:46:53.660000 previous laptime RUS 2.0
# 0 days 00:00:00.347000
# 0.347
#
#
#  2.0
# 0 days 00:46:54.861000 laptime TSU 2.0 #
# 0 days 00:46:54.007000 previous laptime LEC 2.0
# 0 days 00:00:00.854000
# 0.854
#
#
#  2.0
# 0 days 00:46:55.209000 laptime ANT 2.0 #
# 0 days 00:46:54.861000 previous laptime TSU 2.0
# 0 days 00:00:00.348000
# 0.348
#
#
#  2.0
# 0 days 00:46:55.817000 laptime STR 2.0 #
# 0 days 00:46:55.209000 previous laptime ANT 2.0
# 0 days 00:00:00.608000
# 0.608
#
#
#  2.0
# 0 days 00:46:56.450000 laptime NOR 2.0 #
# 0 days 00:46:55.817000 previous laptime STR 2.0
# 0 days 00:00:00.633000
# 0.633
#
#
#  2.0
# 0 days 00:46:57.003000 laptime ALO 2.0 #
# 0 days 00:46:56.450000 previous laptime NOR 2.0
# 0 days 00:00:00.553000
# 0.553
#
#
#  2.0
# 0 days 00:46:57.272000 laptime ALB 2.0 #
# 0 days 00:46:57.003000 previous laptime ALO 2.0
# 0 days 00:00:00.269000
# 0.269
#
#
#  2.0
# 0 days 00:46:57.798000 laptime BEA 2.0 #
# 0 days 00:46:57.272000 previous laptime ALB 2.0
# 0 days 00:00:00.526000
# 0.526
#
#
#  2.0
# 0 days 00:46:58.325000 laptime SAI 2.0 #
# 0 days 00:46:57.798000 previous laptime BEA 2.0
# 0 days 00:00:00.527000
# 0.527
#
#
#  2.0
# 0 days 00:46:58.756000 laptime GAS 2.0 #
# 0 days 00:46:58.325000 previous laptime SAI 2.0
# 0 days 00:00:00.431000
# 0.431
#
#
#  2.0
# 0 days 00:46:59.152000 laptime BOR 2.0 #
# 0 days 00:46:58.756000 previous laptime GAS 2.0
# 0 days 00:00:00.396000
# 0.396
#
#
#  2.0
# 0 days 00:46:59.677000 laptime HAD 2.0 #
# 0 days 00:46:59.152000 previous laptime BOR 2.0
# 0 days 00:00:00.525000
# 0.525
#
#
#  2.0
# 0 days 00:47:00.044000 laptime OCO 2.0 #
# 0 days 00:46:59.677000 previous laptime HAD 2.0
# 0 days 00:00:00.367000
# 0.367
#
#
#  2.0
# 0 days 00:47:00.538000 laptime DOO 2.0 #
# 0 days 00:47:00.044000 previous laptime OCO 2.0
# 0 days 00:00:00.494000
# 0.494
#
#
#  2.0
# 0 days 00:47:01.152000 laptime LAW 2.0 #
# 0 days 00:47:00.538000 previous laptime DOO 2.0
# 0 days 00:00:00.614000
# 0.614
#
#
#  2.0
# 0 days 00:47:02.509000 laptime HUL 2.0 #
# 0 days 00:47:01.152000 previous laptime LAW 2.0
# 0 days 00:00:01.357000
# 1.357
# adding gap 0 for first position
#
#
#  3.0
# 0 days 00:48:26.863000 laptime VER 3.0 #
# 0 days 00:48:25.746000 previous laptime HAM 3.0
# 0 days 00:00:01.117000
# 1.117
#
#
#  3.0
# 0 days 00:48:28.523000 laptime PIA 3.0 #
# 0 days 00:48:26.863000 previous laptime VER 3.0
# 0 days 00:00:01.660000
# 1.6600000000000001
#
#
#  3.0
# 0 days 00:48:30.092000 laptime RUS 3.0 #
# 0 days 00:48:28.523000 previous laptime PIA 3.0
# 0 days 00:00:01.569000
# 1.569
#
#
#  3.0
# 0 days 00:48:30.902000 laptime LEC 3.0 #
# 0 days 00:48:30.092000 previous laptime RUS 3.0
# 0 days 00:00:00.810000
# 0.81
#
#
#  3.0
# 0 days 00:48:31.651000 laptime TSU 3.0 #
# 0 days 00:48:30.902000 previous laptime LEC 3.0
# 0 days 00:00:00.749000
# 0.749
#
#
#  3.0
# 0 days 00:48:32.063000 laptime ANT 3.0 #
# 0 days 00:48:31.651000 previous laptime TSU 3.0
# 0 days 00:00:00.412000
# 0.412
#
#
#  3.0
# 0 days 00:48:32.791000 laptime STR 3.0 #
# 0 days 00:48:32.063000 previous laptime ANT 3.0
# 0 days 00:00:00.728000
# 0.728
#
#
#  3.0
# 0 days 00:48:33.328000 laptime NOR 3.0 #
# 0 days 00:48:32.791000 previous laptime STR 3.0
# 0 days 00:00:00.537000
# 0.537
#
#
#  3.0
# 0 days 00:48:34.299000 laptime ALO 3.0 #
# 0 days 00:48:33.328000 previous laptime NOR 3.0
# 0 days 00:00:00.971000
# 0.971
#
#
#  3.0
# 0 days 00:48:34.815000 laptime ALB 3.0 #
# 0 days 00:48:34.299000 previous laptime ALO 3.0
# 0 days 00:00:00.516000
# 0.516
#
#
#  3.0
# 0 days 00:48:35.634000 laptime BEA 3.0 #
# 0 days 00:48:34.815000 previous laptime ALB 3.0
# 0 days 00:00:00.819000
# 0.819
#
#
#  3.0
# 0 days 00:48:36.347000 laptime SAI 3.0 #
# 0 days 00:48:35.634000 previous laptime BEA 3.0
# 0 days 00:00:00.713000
# 0.713
#
#
#  3.0
# 0 days 00:48:36.775000 laptime GAS 3.0 #
# 0 days 00:48:36.347000 previous laptime SAI 3.0
# 0 days 00:00:00.428000
# 0.428
#
#
#  3.0
# 0 days 00:48:37.282000 laptime BOR 3.0 #
# 0 days 00:48:36.775000 previous laptime GAS 3.0
# 0 days 00:00:00.507000
# 0.507
#
#
#  3.0
# 0 days 00:48:37.816000 laptime HAD 3.0 #
# 0 days 00:48:37.282000 previous laptime BOR 3.0
# 0 days 00:00:00.534000
# 0.534
#
#
#  3.0
# 0 days 00:48:38.334000 laptime OCO 3.0 #
# 0 days 00:48:37.816000 previous laptime HAD 3.0
# 0 days 00:00:00.518000
# 0.518
#
#
#  3.0
# 0 days 00:48:38.874000 laptime DOO 3.0 #
# 0 days 00:48:38.334000 previous laptime OCO 3.0
# 0 days 00:00:00.540000
# 0.54
#
#
#  3.0
# 0 days 00:48:39.499000 laptime LAW 3.0 #
# 0 days 00:48:38.874000 previous laptime DOO 3.0
# 0 days 00:00:00.625000
# 0.625
#
#
#  3.0
# 0 days 00:48:42.042000 laptime HUL 3.0 #
# 0 days 00:48:39.499000 previous laptime LAW 3.0
# 0 days 00:00:02.543000
# 2.543
# adding gap 0 for first position
#
#
#  4.0
# 0 days 00:50:02.860000 laptime VER 4.0 #
# 0 days 00:50:01.897000 previous laptime HAM 4.0
# 0 days 00:00:00.963000
# 0.963
#
#
#  4.0
# 0 days 00:50:04.639000 laptime PIA 4.0 #
# 0 days 00:50:02.860000 previous laptime VER 4.0
# 0 days 00:00:01.779000
# 1.779
#
#
#  4.0
# 0 days 00:50:06.137000 laptime RUS 4.0 #
# 0 days 00:50:04.639000 previous laptime PIA 4.0
# 0 days 00:00:01.498000
# 1.498
#
#
#  4.0
# 0 days 00:50:07.194000 laptime LEC 4.0 #
# 0 days 00:50:06.137000 previous laptime RUS 4.0
# 0 days 00:00:01.057000
# 1.057
#
#
#  4.0
# 0 days 00:50:08.139000 laptime TSU 4.0 #
# 0 days 00:50:07.194000 previous laptime LEC 4.0
# 0 days 00:00:00.945000
# 0.945
#
#
#  4.0
# 0 days 00:50:08.722000 laptime ANT 4.0 #
# 0 days 00:50:08.139000 previous laptime TSU 4.0
# 0 days 00:00:00.583000
# 0.583
#
#
#  4.0
# 0 days 00:50:09.705000 laptime STR 4.0 #
# 0 days 00:50:08.722000 previous laptime ANT 4.0
# 0 days 00:00:00.983000
# 0.983
#
#
#  4.0
# 0 days 00:50:10.429000 laptime NOR 4.0 #
# 0 days 00:50:09.705000 previous laptime STR 4.0
# 0 days 00:00:00.724000
# 0.724
#
#
#  4.0
# 0 days 00:50:11.804000 laptime ALO 4.0 #
# 0 days 00:50:10.429000 previous laptime NOR 4.0
# 0 days 00:00:01.375000
# 1.375
#
#
#  4.0
# 0 days 00:50:12.162000 laptime ALB 4.0 #
# 0 days 00:50:11.804000 previous laptime ALO 4.0
# 0 days 00:00:00.358000
# 0.358
#
#
#  4.0
# 0 days 00:50:12.769000 laptime BEA 4.0 #
# 0 days 00:50:12.162000 previous laptime ALB 4.0
# 0 days 00:00:00.607000
# 0.607
#
#
#  4.0
# 0 days 00:50:13.649000 laptime SAI 4.0 #
# 0 days 00:50:12.769000 previous laptime BEA 4.0
# 0 days 00:00:00.880000
# 0.88
#
#
#  4.0
# 0 days 00:50:14.256000 laptime GAS 4.0 #
# 0 days 00:50:13.649000 previous laptime SAI 4.0
# 0 days 00:00:00.607000
# 0.607
#
#
#  4.0
# 0 days 00:50:14.757000 laptime BOR 4.0 #
# 0 days 00:50:14.256000 previous laptime GAS 4.0
# 0 days 00:00:00.501000
# 0.501
#
#
#  4.0
# 0 days 00:50:15.365000 laptime HAD 4.0 #
# 0 days 00:50:14.757000 previous laptime BOR 4.0
# 0 days 00:00:00.608000
# 0.608
#
#
#  4.0
# 0 days 00:50:15.888000 laptime OCO 4.0 #
# 0 days 00:50:15.365000 previous laptime HAD 4.0
# 0 days 00:00:00.523000
# 0.523
#
#
#  4.0
# 0 days 00:50:17.223000 laptime LAW 4.0 #
# 0 days 00:50:15.888000 previous laptime OCO 4.0
# 0 days 00:00:01.335000
# 1.335
#
#
#  4.0
# 0 days 00:50:16.560000 laptime DOO 4.0 #
# 0 days 00:50:17.223000 previous laptime LAW 4.0
# -1 days +23:59:59.337000
# -0.663
#
#
#  4.0
# 0 days 00:50:18.846000 laptime HUL 4.0 #
# 0 days 00:50:16.560000 previous laptime DOO 4.0
# 0 days 00:00:02.286000
# 2.286
# adding gap 0 for first position
#
#
#  5.0
# 0 days 00:51:38.943000 laptime VER 5.0 #
# 0 days 00:51:37.961000 previous laptime HAM 5.0
# 0 days 00:00:00.982000
# 0.982
#
#
#  5.0
# 0 days 00:51:40.532000 laptime PIA 5.0 #
# 0 days 00:51:38.943000 previous laptime VER 5.0
# 0 days 00:00:01.589000
# 1.589
#
#
#  5.0
# 0 days 00:51:42.028000 laptime RUS 5.0 #
# 0 days 00:51:40.532000 previous laptime PIA 5.0
# 0 days 00:00:01.496000
# 1.496
#
#
#  5.0
# 0 days 00:51:43.449000 laptime LEC 5.0 #
# 0 days 00:51:42.028000 previous laptime RUS 5.0
# 0 days 00:00:01.421000
# 1.421
#
#
#  5.0
# 0 days 00:51:44.527000 laptime TSU 5.0 #
# 0 days 00:51:43.449000 previous laptime LEC 5.0
# 0 days 00:00:01.078000
# 1.078
#
#
#  5.0
# 0 days 00:51:45.240000 laptime ANT 5.0 #
# 0 days 00:51:44.527000 previous laptime TSU 5.0
# 0 days 00:00:00.713000
# 0.713
#
#
#  5.0
# 0 days 00:51:46.140000 laptime STR 5.0 #
# 0 days 00:51:45.240000 previous laptime ANT 5.0
# 0 days 00:00:00.900000
# 0.9
#
#
#  5.0
# 0 days 00:51:47.137000 laptime NOR 5.0 #
# 0 days 00:51:46.140000 previous laptime STR 5.0
# 0 days 00:00:00.997000
# 0.997
#
#
#  5.0
# 0 days 00:51:49.277000 laptime ALO 5.0 #
# 0 days 00:51:47.137000 previous laptime NOR 5.0
# 0 days 00:00:02.140000
# 2.14
#
#
#  5.0
# 0 days 00:51:49.857000 laptime ALB 5.0 #
# 0 days 00:51:49.277000 previous laptime ALO 5.0
# 0 days 00:00:00.580000
# 0.58
#
#
#  5.0
# 0 days 00:51:50.728000 laptime BEA 5.0 #
# 0 days 00:51:49.857000 previous laptime ALB 5.0
# 0 days 00:00:00.871000
# 0.871
#
#
#  5.0
# 0 days 00:51:51.354000 laptime SAI 5.0 #
# 0 days 00:51:50.728000 previous laptime BEA 5.0
# 0 days 00:00:00.626000
# 0.626
#
#
#  5.0
# 0 days 00:51:51.953000 laptime GAS 5.0 #
# 0 days 00:51:51.354000 previous laptime SAI 5.0
# 0 days 00:00:00.599000
# 0.599
#
#
#  5.0
# 0 days 00:51:52.365000 laptime BOR 5.0 #
# 0 days 00:51:51.953000 previous laptime GAS 5.0
# 0 days 00:00:00.412000
# 0.412
#
#
#  5.0
# 0 days 00:51:52.950000 laptime HAD 5.0 #
# 0 days 00:51:52.365000 previous laptime BOR 5.0
# 0 days 00:00:00.585000
# 0.585
#
#
#  5.0
# 0 days 00:51:53.520000 laptime OCO 5.0 #
# 0 days 00:51:52.950000 previous laptime HAD 5.0
# 0 days 00:00:00.570000
# 0.57
#
#
#  5.0
# 0 days 00:51:54.386000 laptime LAW 5.0 #
# 0 days 00:51:53.520000 previous laptime OCO 5.0
# 0 days 00:00:00.866000
# 0.866
#
#
#  5.0
# 0 days 00:51:54.661000 laptime DOO 5.0 #
# 0 days 00:51:54.386000 previous laptime LAW 5.0
# 0 days 00:00:00.275000
# 0.275
#
#
#  5.0
# 0 days 00:51:55.375000 laptime HUL 5.0 #
# 0 days 00:51:54.661000 previous laptime DOO 5.0
# 0 days 00:00:00.714000
# 0.714
# adding gap 0 for first position
#
#
#  6.0
# 0 days 00:53:15.671000 laptime VER 6.0 #
# 0 days 00:53:14.645000 previous laptime HAM 6.0
# 0 days 00:00:01.026000
# 1.026
#
#
#  6.0
# 0 days 00:53:16.881000 laptime PIA 6.0 #
# 0 days 00:53:15.671000 previous laptime VER 6.0
# 0 days 00:00:01.210000
# 1.21
#
#
#  6.0
# 0 days 00:53:18.422000 laptime RUS 6.0 #
# 0 days 00:53:16.881000 previous laptime PIA 6.0
# 0 days 00:00:01.541000
# 1.541
#
#
#  6.0
# 0 days 00:53:19.973000 laptime LEC 6.0 #
# 0 days 00:53:18.422000 previous laptime RUS 6.0
# 0 days 00:00:01.551000
# 1.5510000000000002
#
#
#  6.0
# 0 days 00:53:21.054000 laptime TSU 6.0 #
# 0 days 00:53:19.973000 previous laptime LEC 6.0
# 0 days 00:00:01.081000
# 1.081
#
#
#  6.0
# 0 days 00:53:21.551000 laptime ANT 6.0 #
# 0 days 00:53:21.054000 previous laptime TSU 6.0
# 0 days 00:00:00.497000
# 0.497
#
#
#  6.0
# 0 days 00:53:23.043000 laptime STR 6.0 #
# 0 days 00:53:21.551000 previous laptime ANT 6.0
# 0 days 00:00:01.492000
# 1.492
#
#
#  6.0
# 0 days 00:53:24.674000 laptime NOR 6.0 #
# 0 days 00:53:23.043000 previous laptime STR 6.0
# 0 days 00:00:01.631000
# 1.631
#
#
#  6.0
# 0 days 00:53:26.880000 laptime ALO 6.0 #
# 0 days 00:53:24.674000 previous laptime NOR 6.0
# 0 days 00:00:02.206000
# 2.206
#
#
#  6.0
# 0 days 00:53:27.427000 laptime ALB 6.0 #
# 0 days 00:53:26.880000 previous laptime ALO 6.0
# 0 days 00:00:00.547000
# 0.547
#
#
#  6.0
# 0 days 00:53:28.422000 laptime BEA 6.0 #
# 0 days 00:53:27.427000 previous laptime ALB 6.0
# 0 days 00:00:00.995000
# 0.995
#
#
#  6.0
# 0 days 00:53:29.157000 laptime SAI 6.0 #
# 0 days 00:53:28.422000 previous laptime BEA 6.0
# 0 days 00:00:00.735000
# 0.735
#
#
#  6.0
# 0 days 00:53:29.791000 laptime GAS 6.0 #
# 0 days 00:53:29.157000 previous laptime SAI 6.0
# 0 days 00:00:00.634000
# 0.634
#
#
#  6.0
# 0 days 00:53:30.328000 laptime BOR 6.0 #
# 0 days 00:53:29.791000 previous laptime GAS 6.0
# 0 days 00:00:00.537000
# 0.537
#
#
#  6.0
# 0 days 00:53:30.865000 laptime HAD 6.0 #
# 0 days 00:53:30.328000 previous laptime BOR 6.0
# 0 days 00:00:00.537000
# 0.537
#
#
#  6.0
# 0 days 00:53:32.015000 laptime LAW 6.0 #
# 0 days 00:53:30.865000 previous laptime HAD 6.0
# 0 days 00:00:01.150000
# 1.15
#
#
#  6.0
# 0 days 00:53:31.274000 laptime OCO 6.0 #
# 0 days 00:53:32.015000 previous laptime LAW 6.0
# -1 days +23:59:59.259000
# -0.741
#
#
#  6.0
# 0 days 00:53:32.541000 laptime DOO 6.0 #
# 0 days 00:53:31.274000 previous laptime OCO 6.0
# 0 days 00:00:01.267000
# 1.267
#
#
#  6.0
# 0 days 00:53:33.136000 laptime HUL 6.0 #
# 0 days 00:53:32.541000 previous laptime DOO 6.0
# 0 days 00:00:00.595000
# 0.595
# adding gap 0 for first position
#
#
#  7.0
# 0 days 00:54:52.334000 laptime VER 7.0 #
# 0 days 00:54:50.994000 previous laptime HAM 7.0
# 0 days 00:00:01.340000
# 1.34
#
#
#  7.0
# 0 days 00:54:53.197000 laptime PIA 7.0 #
# 0 days 00:54:52.334000 previous laptime VER 7.0
# 0 days 00:00:00.863000
# 0.863
#
#
#  7.0
# 0 days 00:54:54.783000 laptime RUS 7.0 #
# 0 days 00:54:53.197000 previous laptime PIA 7.0
# 0 days 00:00:01.586000
# 1.5859999999999999
#
#
#  7.0
# 0 days 00:54:56.317000 laptime LEC 7.0 #
# 0 days 00:54:54.783000 previous laptime RUS 7.0
# 0 days 00:00:01.534000
# 1.534
#
#
#  7.0
# 0 days 00:54:57.904000 laptime TSU 7.0 #
# 0 days 00:54:56.317000 previous laptime LEC 7.0
# 0 days 00:00:01.587000
# 1.587
#
#
#  7.0
# 0 days 00:54:58.410000 laptime ANT 7.0 #
# 0 days 00:54:57.904000 previous laptime TSU 7.0
# 0 days 00:00:00.506000
# 0.506
#
#
#  7.0
# 0 days 00:55:00.118000 laptime STR 7.0 #
# 0 days 00:54:58.410000 previous laptime ANT 7.0
# 0 days 00:00:01.708000
# 1.708
#
#
#  7.0
# 0 days 00:55:01.753000 laptime NOR 7.0 #
# 0 days 00:55:00.118000 previous laptime STR 7.0
# 0 days 00:00:01.635000
# 1.635
#
#
#  7.0
# 0 days 00:55:04.503000 laptime ALO 7.0 #
# 0 days 00:55:01.753000 previous laptime NOR 7.0
# 0 days 00:00:02.750000
# 2.75
#
#
#  7.0
# 0 days 00:55:05.027000 laptime ALB 7.0 #
# 0 days 00:55:04.503000 previous laptime ALO 7.0
# 0 days 00:00:00.524000
# 0.524
#
#
#  7.0
# 0 days 00:55:06.315000 laptime BEA 7.0 #
# 0 days 00:55:05.027000 previous laptime ALB 7.0
# 0 days 00:00:01.288000
# 1.288
#
#
#  7.0
# 0 days 00:55:07.042000 laptime SAI 7.0 #
# 0 days 00:55:06.315000 previous laptime BEA 7.0
# 0 days 00:00:00.727000
# 0.727
#
#
#  7.0
# 0 days 00:55:07.696000 laptime GAS 7.0 #
# 0 days 00:55:07.042000 previous laptime SAI 7.0
# 0 days 00:00:00.654000
# 0.654
#
#
#  7.0
# 0 days 00:55:08.780000 laptime HAD 7.0 #
# 0 days 00:55:07.696000 previous laptime GAS 7.0
# 0 days 00:00:01.084000
# 1.084
#
#
#  7.0
# 0 days 00:55:08.229000 laptime BOR 7.0 #
# 0 days 00:55:08.780000 previous laptime HAD 7.0
# -1 days +23:59:59.449000
# -0.5509999999999999
#
#
#  7.0
# 0 days 00:55:09.524000 laptime LAW 7.0 #
# 0 days 00:55:08.229000 previous laptime BOR 7.0
# 0 days 00:00:01.295000
# 1.295
#
#
#  7.0
# 0 days 00:55:09.853000 laptime OCO 7.0 #
# 0 days 00:55:09.524000 previous laptime LAW 7.0
# 0 days 00:00:00.329000
# 0.329
#
#
#  7.0
# 0 days 00:55:10.344000 laptime DOO 7.0 #
# 0 days 00:55:09.853000 previous laptime OCO 7.0
# 0 days 00:00:00.491000
# 0.491
#
#
#  7.0
# 0 days 00:55:11.104000 laptime HUL 7.0 #
# 0 days 00:55:10.344000 previous laptime DOO 7.0
# 0 days 00:00:00.760000
# 0.76
# adding gap 0 for first position
#
#
#  8.0
# 0 days 00:56:28.277000 laptime VER 8.0 #
# 0 days 00:56:27.611000 previous laptime HAM 8.0
# 0 days 00:00:00.666000
# 0.666
#
#
#  8.0
# 0 days 00:56:29.051000 laptime PIA 8.0 #
# 0 days 00:56:28.277000 previous laptime VER 8.0
# 0 days 00:00:00.774000
# 0.774
#
#
#  8.0
# 0 days 00:56:31.436000 laptime RUS 8.0 #
# 0 days 00:56:29.051000 previous laptime PIA 8.0
# 0 days 00:00:02.385000
# 2.385
#
#
#  8.0
# 0 days 00:56:32.960000 laptime LEC 8.0 #
# 0 days 00:56:31.436000 previous laptime RUS 8.0
# 0 days 00:00:01.524000
# 1.524
#
#
#  8.0
# 0 days 00:56:34.704000 laptime TSU 8.0 #
# 0 days 00:56:32.960000 previous laptime LEC 8.0
# 0 days 00:00:01.744000
# 1.744
#
#
#  8.0
# 0 days 00:56:35.121000 laptime ANT 8.0 #
# 0 days 00:56:34.704000 previous laptime TSU 8.0
# 0 days 00:00:00.417000
# 0.417
#
#
#  8.0
# 0 days 00:56:37.013000 laptime STR 8.0 #
# 0 days 00:56:35.121000 previous laptime ANT 8.0
# 0 days 00:00:01.892000
# 1.892
#
#
#  8.0
# 0 days 00:56:38.851000 laptime NOR 8.0 #
# 0 days 00:56:37.013000 previous laptime STR 8.0
# 0 days 00:00:01.838000
# 1.838
#
#
#  8.0
# 0 days 00:56:41.772000 laptime ALO 8.0 #
# 0 days 00:56:38.851000 previous laptime NOR 8.0
# 0 days 00:00:02.921000
# 2.9210000000000003
#
#
#  8.0
# 0 days 00:56:42.371000 laptime ALB 8.0 #
# 0 days 00:56:41.772000 previous laptime ALO 8.0
# 0 days 00:00:00.599000
# 0.599
#
#
#  8.0
# 0 days 00:56:44.054000 laptime BEA 8.0 #
# 0 days 00:56:42.371000 previous laptime ALB 8.0
# 0 days 00:00:01.683000
# 1.683
#
#
#  8.0
# 0 days 00:56:44.985000 laptime SAI 8.0 #
# 0 days 00:56:44.054000 previous laptime BEA 8.0
# 0 days 00:00:00.931000
# 0.931
#
#
#  8.0
# 0 days 00:56:45.593000 laptime GAS 8.0 #
# 0 days 00:56:44.985000 previous laptime SAI 8.0
# 0 days 00:00:00.608000
# 0.608
#
#
#  8.0
# 0 days 00:56:46.511000 laptime HAD 8.0 #
# 0 days 00:56:45.593000 previous laptime GAS 8.0
# 0 days 00:00:00.918000
# 0.918
#
#
#  8.0
# 0 days 00:56:46.851000 laptime BOR 8.0 #
# 0 days 00:56:46.511000 previous laptime HAD 8.0
# 0 days 00:00:00.340000
# 0.34
#
#
#  8.0
# 0 days 00:56:47.597000 laptime LAW 8.0 #
# 0 days 00:56:46.851000 previous laptime BOR 8.0
# 0 days 00:00:00.746000
# 0.746
#
#
#  8.0
# 0 days 00:56:48.122000 laptime OCO 8.0 #
# 0 days 00:56:47.597000 previous laptime LAW 8.0
# 0 days 00:00:00.525000
# 0.525
#
#
#  8.0
# 0 days 00:56:48.580000 laptime DOO 8.0 #
# 0 days 00:56:48.122000 previous laptime OCO 8.0
# 0 days 00:00:00.458000
# 0.458
#
#
#  8.0
# 0 days 00:56:49.597000 laptime HUL 8.0 #
# 0 days 00:56:48.580000 previous laptime DOO 8.0
# 0 days 00:00:01.017000
# 1.017
# adding gap 0 for first position
#
#
#  9.0
# 0 days 00:58:04.232000 laptime VER 9.0 #
# 0 days 00:58:03.614000 previous laptime HAM 9.0
# 0 days 00:00:00.618000
# 0.618
#
#
#  9.0
# 0 days 00:58:05.717000 laptime PIA 9.0 #
# 0 days 00:58:04.232000 previous laptime VER 9.0
# 0 days 00:00:01.485000
# 1.4849999999999999
#
#
#  9.0
# 0 days 00:58:08.155000 laptime RUS 9.0 #
# 0 days 00:58:05.717000 previous laptime PIA 9.0
# 0 days 00:00:02.438000
# 2.438
#
#
#  9.0
# 0 days 00:58:09.974000 laptime LEC 9.0 #
# 0 days 00:58:08.155000 previous laptime RUS 9.0
# 0 days 00:00:01.819000
# 1.819
#
#
#  9.0
# 0 days 00:58:11.880000 laptime TSU 9.0 #
# 0 days 00:58:09.974000 previous laptime LEC 9.0
# 0 days 00:00:01.906000
# 1.9060000000000001
#
#
#  9.0
# 0 days 00:58:12.380000 laptime ANT 9.0 #
# 0 days 00:58:11.880000 previous laptime TSU 9.0
# 0 days 00:00:00.500000
# 0.5
#
#
#  9.0
# 0 days 00:58:14.149000 laptime STR 9.0 #
# 0 days 00:58:12.380000 previous laptime ANT 9.0
# 0 days 00:00:01.769000
# 1.7690000000000001
#
#
#  9.0
# 0 days 00:58:16.113000 laptime NOR 9.0 #
# 0 days 00:58:14.149000 previous laptime STR 9.0
# 0 days 00:00:01.964000
# 1.964
#
#
#  9.0
# 0 days 00:58:18.830000 laptime ALO 9.0 #
# 0 days 00:58:16.113000 previous laptime NOR 9.0
# 0 days 00:00:02.717000
# 2.717
#
#
#  9.0
# 0 days 00:58:20.258000 laptime ALB 9.0 #
# 0 days 00:58:18.830000 previous laptime ALO 9.0
# 0 days 00:00:01.428000
# 1.428
#
#
#  9.0
# 0 days 00:58:22.291000 laptime BEA 9.0 #
# 0 days 00:58:20.258000 previous laptime ALB 9.0
# 0 days 00:00:02.033000
# 2.033
#
#
#  9.0
# 0 days 00:58:23.375000 laptime SAI 9.0 #
# 0 days 00:58:22.291000 previous laptime BEA 9.0
# 0 days 00:00:01.084000
# 1.084
#
#
#  9.0
# 0 days 00:58:24.658000 laptime HAD 9.0 #
# 0 days 00:58:23.375000 previous laptime SAI 9.0
# 0 days 00:00:01.283000
# 1.283
#
#
#  9.0
# 0 days 00:58:24.262000 laptime GAS 9.0 #
# 0 days 00:58:24.658000 previous laptime HAD 9.0
# -1 days +23:59:59.604000
# -0.396
#
#
#  9.0
# 0 days 00:58:25.204000 laptime BOR 9.0 #
# 0 days 00:58:24.262000 previous laptime GAS 9.0
# 0 days 00:00:00.942000
# 0.942
#
#
#  9.0
# 0 days 00:58:25.710000 laptime LAW 9.0 #
# 0 days 00:58:25.204000 previous laptime BOR 9.0
# 0 days 00:00:00.506000
# 0.506
#
#
#  9.0
# 0 days 00:58:26.565000 laptime OCO 9.0 #
# 0 days 00:58:25.710000 previous laptime LAW 9.0
# 0 days 00:00:00.855000
# 0.855
#
#
#  9.0
# 0 days 00:58:26.999000 laptime DOO 9.0 #
# 0 days 00:58:26.565000 previous laptime OCO 9.0
# 0 days 00:00:00.434000
# 0.434
#
#
#  9.0
# 0 days 00:58:27.825000 laptime HUL 9.0 #
# 0 days 00:58:26.999000 previous laptime DOO 9.0
# 0 days 00:00:00.826000
# 0.826
# adding gap 0 for first position
#
#
#  10.0
# 0 days 00:59:41.676000 laptime VER 10.0 #
# 0 days 00:59:40.555000 previous laptime HAM 10.0
# 0 days 00:00:01.121000
# 1.121
#
#
#  10.0
# 0 days 00:59:42.874000 laptime PIA 10.0 #
# 0 days 00:59:41.676000 previous laptime VER 10.0
# 0 days 00:00:01.198000
# 1.198
#
#
#  10.0
# 0 days 00:59:45.104000 laptime RUS 10.0 #
# 0 days 00:59:42.874000 previous laptime PIA 10.0
# 0 days 00:00:02.230000
# 2.23
#
#
#  10.0
# 0 days 00:59:47.262000 laptime LEC 10.0 #
# 0 days 00:59:45.104000 previous laptime RUS 10.0
# 0 days 00:00:02.158000
# 2.158
#
#
#  10.0
# 0 days 00:59:49.324000 laptime TSU 10.0 #
# 0 days 00:59:47.262000 previous laptime LEC 10.0
# 0 days 00:00:02.062000
# 2.062
#
#
#  10.0
# 0 days 00:59:49.698000 laptime ANT 10.0 #
# 0 days 00:59:49.324000 previous laptime TSU 10.0
# 0 days 00:00:00.374000
# 0.374
#
#
#  10.0
# 0 days 00:59:51.469000 laptime STR 10.0 #
# 0 days 00:59:49.698000 previous laptime ANT 10.0
# 0 days 00:00:01.771000
# 1.771
#
#
#  10.0
# 0 days 00:59:53.995000 laptime NOR 10.0 #
# 0 days 00:59:51.469000 previous laptime STR 10.0
# 0 days 00:00:02.526000
# 2.526
#
#
#  10.0
# 0 days 00:59:56.476000 laptime ALO 10.0 #
# 0 days 00:59:53.995000 previous laptime NOR 10.0
# 0 days 00:00:02.481000
# 2.481
#
#
#  10.0
# 0 days 00:59:58.770000 laptime ALB 10.0 #
# 0 days 00:59:56.476000 previous laptime ALO 10.0
# 0 days 00:00:02.294000
# 2.294
#
#
#  10.0
# 0 days 01:00:00.661000 laptime BEA 10.0 #
# 0 days 00:59:58.770000 previous laptime ALB 10.0
# 0 days 00:00:01.891000
# 1.891
#
#
#  10.0
# 0 days 01:00:03.731000 laptime GAS 10.0 #
# 0 days 01:00:00.661000 previous laptime BEA 10.0
# 0 days 00:00:03.070000
# 3.07
#
#
#  10.0
# 0 days 01:00:02.724000 laptime SAI 10.0 #
# 0 days 01:00:03.731000 previous laptime GAS 10.0
# -1 days +23:59:58.993000
# -1.0070000000000001
#
#
#  10.0
# 0 days 01:00:03.512000 laptime HAD 10.0 #
# 0 days 01:00:02.724000 previous laptime SAI 10.0
# 0 days 00:00:00.788000
# 0.788
#
#
#  10.0
# 0 days 01:00:04.354000 laptime LAW 10.0 #
# 0 days 01:00:03.512000 previous laptime HAD 10.0
# 0 days 00:00:00.842000
# 0.842
#
#
#  10.0
# 0 days 01:00:04.153000 laptime BOR 10.0 #
# 0 days 01:00:04.354000 previous laptime LAW 10.0
# -1 days +23:59:59.799000
# -0.20099999999999996
#
#
#  10.0
# 0 days 01:00:05.079000 laptime OCO 10.0 #
# 0 days 01:00:04.153000 previous laptime BOR 10.0
# 0 days 00:00:00.926000
# 0.926
#
#
#  10.0
# 0 days 01:00:05.448000 laptime DOO 10.0 #
# 0 days 01:00:05.079000 previous laptime OCO 10.0
# 0 days 00:00:00.369000
# 0.369
#
#
#  10.0
# 0 days 01:00:06.376000 laptime HUL 10.0 #
# 0 days 01:00:05.448000 previous laptime DOO 10.0
# 0 days 00:00:00.928000
# 0.928
# adding gap 0 for first position
#
#
#  11.0
# 0 days 01:01:18.726000 laptime VER 11.0 #
# 0 days 01:01:17.427000 previous laptime HAM 11.0
# 0 days 00:00:01.299000
# 1.299
#
#
#  11.0
# 0 days 01:01:19.273000 laptime PIA 11.0 #
# 0 days 01:01:18.726000 previous laptime VER 11.0
# 0 days 00:00:00.547000
# 0.547
#
#
#  11.0
# 0 days 01:01:22.427000 laptime RUS 11.0 #
# 0 days 01:01:19.273000 previous laptime PIA 11.0
# 0 days 00:00:03.154000
# 3.154
#
#
#  11.0
# 0 days 01:01:24.892000 laptime LEC 11.0 #
# 0 days 01:01:22.427000 previous laptime RUS 11.0
# 0 days 00:00:02.465000
# 2.465
#
#
#  11.0
# 0 days 01:01:26.966000 laptime TSU 11.0 #
# 0 days 01:01:24.892000 previous laptime LEC 11.0
# 0 days 00:00:02.074000
# 2.074
#
#
#  11.0
# 0 days 01:01:27.443000 laptime ANT 11.0 #
# 0 days 01:01:26.966000 previous laptime TSU 11.0
# 0 days 00:00:00.477000
# 0.477
#
#
#  11.0
# 0 days 01:01:28.699000 laptime STR 11.0 #
# 0 days 01:01:27.443000 previous laptime ANT 11.0
# 0 days 00:00:01.256000
# 1.256
#
#
#  11.0
# 0 days 01:01:31.864000 laptime NOR 11.0 #
# 0 days 01:01:28.699000 previous laptime STR 11.0
# 0 days 00:00:03.165000
# 3.165
#
#
#  11.0
# 0 days 01:01:34.517000 laptime ALO 11.0 #
# 0 days 01:01:31.864000 previous laptime NOR 11.0
# 0 days 00:00:02.653000
# 2.653
#
#
#  11.0
# 0 days 01:01:37.062000 laptime ALB 11.0 #
# 0 days 01:01:34.517000 previous laptime ALO 11.0
# 0 days 00:00:02.545000
# 2.545
#
#
#  11.0
# 0 days 01:01:38.974000 laptime BEA 11.0 #
# 0 days 01:01:37.062000 previous laptime ALB 11.0
# 0 days 00:00:01.912000
# 1.912
#
#
#  11.0
# 0 days 01:01:41.947000 laptime GAS 11.0 #
# 0 days 01:01:38.974000 previous laptime BEA 11.0
# 0 days 00:00:02.973000
# 2.973
#
#
#  11.0
# 0 days 01:01:42.757000 laptime HAD 11.0 #
# 0 days 01:01:41.947000 previous laptime GAS 11.0
# 0 days 00:00:00.810000
# 0.81
#
#
#  11.0
# 0 days 01:01:43.442000 laptime LAW 11.0 #
# 0 days 01:01:42.757000 previous laptime HAD 11.0
# 0 days 00:00:00.685000
# 0.685
#
#
#  11.0
# 0 days 01:01:44.070000 laptime BOR 11.0 #
# 0 days 01:01:43.442000 previous laptime LAW 11.0
# 0 days 00:00:00.628000
# 0.628
#
#
#  11.0
# 0 days 01:01:44.472000 laptime OCO 11.0 #
# 0 days 01:01:44.070000 previous laptime BOR 11.0
# 0 days 00:00:00.402000
# 0.402
#
#
#  11.0
# 0 days 01:01:44.789000 laptime DOO 11.0 #
# 0 days 01:01:44.472000 previous laptime OCO 11.0
# 0 days 00:00:00.317000
# 0.317
#
#
#  11.0
# 0 days 01:01:45.444000 laptime HUL 11.0 #
# 0 days 01:01:44.789000 previous laptime DOO 11.0
# 0 days 00:00:00.655000
# 0.655
#
#
#  11.0
# 0 days 01:01:42.475000 laptime SAI 11.0 #
# 0 days 01:01:45.444000 previous laptime HUL 11.0
# -1 days +23:59:57.031000
# -2.969
# adding gap 0 for first position
#
#
#  12.0
# 0 days 01:02:55.585000 laptime VER 12.0 #
# 0 days 01:02:54.129000 previous laptime HAM 12.0
# 0 days 00:00:01.456000
# 1.456
#
#
#  12.0
# 0 days 01:02:56.124000 laptime PIA 12.0 #
# 0 days 01:02:55.585000 previous laptime VER 12.0
# 0 days 00:00:00.539000
# 0.539
#
#
#  12.0
# 0 days 01:03:00.180000 laptime RUS 12.0 #
# 0 days 01:02:56.124000 previous laptime PIA 12.0
# 0 days 00:00:04.056000
# 4.056
#
#
#  12.0
# 0 days 01:03:02.913000 laptime LEC 12.0 #
# 0 days 01:03:00.180000 previous laptime RUS 12.0
# 0 days 00:00:02.733000
# 2.733
#
#
#  12.0
# 0 days 01:03:05.151000 laptime TSU 12.0 #
# 0 days 01:03:02.913000 previous laptime LEC 12.0
# 0 days 00:00:02.238000
# 2.238
#
#
#  12.0
# 0 days 01:03:05.709000 laptime ANT 12.0 #
# 0 days 01:03:05.151000 previous laptime TSU 12.0
# 0 days 00:00:00.558000
# 0.558
#
#
#  12.0
# 0 days 01:03:06.761000 laptime STR 12.0 #
# 0 days 01:03:05.709000 previous laptime ANT 12.0
# 0 days 00:00:01.052000
# 1.052
#
#
#  12.0
# 0 days 01:03:10.091000 laptime NOR 12.0 #
# 0 days 01:03:06.761000 previous laptime STR 12.0
# 0 days 00:00:03.330000
# 3.33
#
#
#  12.0
# 0 days 01:03:12.901000 laptime ALO 12.0 #
# 0 days 01:03:10.091000 previous laptime NOR 12.0
# 0 days 00:00:02.810000
# 2.81
#
#
#  12.0
# 0 days 01:03:15.326000 laptime ALB 12.0 #
# 0 days 01:03:12.901000 previous laptime ALO 12.0
# 0 days 00:00:02.425000
# 2.425
#
#
#  12.0
# 0 days 01:03:17.334000 laptime BEA 12.0 #
# 0 days 01:03:15.326000 previous laptime ALB 12.0
# 0 days 00:00:02.008000
# 2.008
#
#
#  12.0
# 0 days 01:03:20.808000 laptime GAS 12.0 #
# 0 days 01:03:17.334000 previous laptime BEA 12.0
# 0 days 00:00:03.474000
# 3.474
#
#
#  12.0
# 0 days 01:03:22.556000 laptime HAD 12.0 #
# 0 days 01:03:20.808000 previous laptime GAS 12.0
# 0 days 00:00:01.748000
# 1.748
#
#
#  12.0
# 0 days 01:03:23.185000 laptime LAW 12.0 #
# 0 days 01:03:22.556000 previous laptime HAD 12.0
# 0 days 00:00:00.629000
# 0.629
#
#
#  12.0
# 0 days 01:03:23.953000 laptime BOR 12.0 #
# 0 days 01:03:23.185000 previous laptime LAW 12.0
# 0 days 00:00:00.768000
# 0.768
#
#
#  12.0
# 0 days 01:03:24.609000 laptime OCO 12.0 #
# 0 days 01:03:23.953000 previous laptime BOR 12.0
# 0 days 00:00:00.656000
# 0.656
#
#
#  12.0
# 0 days 01:03:24.893000 laptime DOO 12.0 #
# 0 days 01:03:24.609000 previous laptime OCO 12.0
# 0 days 00:00:00.284000
# 0.284
#
#
#  12.0
# 0 days 01:03:25.474000 laptime HUL 12.0 #
# 0 days 01:03:24.893000 previous laptime DOO 12.0
# 0 days 00:00:00.581000
# 0.581
#
#
#  12.0
# 0 days 01:03:28.675000 laptime SAI 12.0 #
# 0 days 01:03:25.474000 previous laptime HUL 12.0
# 0 days 00:00:03.201000
# 3.201
# adding gap 0 for first position
#
#
#  13.0
# 0 days 01:04:32.824000 laptime VER 13.0 #
# 0 days 01:04:31.055000 previous laptime HAM 13.0
# 0 days 00:00:01.769000
# 1.7690000000000001
#
#
#  13.0
# 0 days 01:04:33.450000 laptime PIA 13.0 #
# 0 days 01:04:32.824000 previous laptime VER 13.0
# 0 days 00:00:00.626000
# 0.626
#
#
#  13.0
# 0 days 01:04:37.868000 laptime RUS 13.0 #
# 0 days 01:04:33.450000 previous laptime PIA 13.0
# 0 days 00:00:04.418000
# 4.418
#
#
#  13.0
# 0 days 01:04:41.139000 laptime LEC 13.0 #
# 0 days 01:04:37.868000 previous laptime RUS 13.0
# 0 days 00:00:03.271000
# 3.271
#
#
#  13.0
# 0 days 01:04:43.325000 laptime TSU 13.0 #
# 0 days 01:04:41.139000 previous laptime LEC 13.0
# 0 days 00:00:02.186000
# 2.186
#
#
#  13.0
# 0 days 01:04:44.015000 laptime ANT 13.0 #
# 0 days 01:04:43.325000 previous laptime TSU 13.0
# 0 days 00:00:00.690000
# 0.69
#
#
#  13.0
# 0 days 01:04:44.981000 laptime STR 13.0 #
# 0 days 01:04:44.015000 previous laptime ANT 13.0
# 0 days 00:00:00.966000
# 0.966
#
#
#  13.0
# 0 days 01:04:47.711000 laptime NOR 13.0 #
# 0 days 01:04:44.981000 previous laptime STR 13.0
# 0 days 00:00:02.730000
# 2.73
#
#
#  13.0
# 0 days 01:04:51.787000 laptime ALO 13.0 #
# 0 days 01:04:47.711000 previous laptime NOR 13.0
# 0 days 00:00:04.076000
# 4.076
#
#
#  13.0
# 0 days 01:04:53.652000 laptime ALB 13.0 #
# 0 days 01:04:51.787000 previous laptime ALO 13.0
# 0 days 00:00:01.865000
# 1.865
#
#
#  13.0
# 0 days 01:04:56.357000 laptime BEA 13.0 #
# 0 days 01:04:53.652000 previous laptime ALB 13.0
# 0 days 00:00:02.705000
# 2.705
#
#
#  13.0
# 0 days 01:04:59.720000 laptime GAS 13.0 #
# 0 days 01:04:56.357000 previous laptime BEA 13.0
# 0 days 00:00:03.363000
# 3.363
#
#
#  13.0
# 0 days 01:05:00.929000 laptime HAD 13.0 #
# 0 days 01:04:59.720000 previous laptime GAS 13.0
# 0 days 00:00:01.209000
# 1.209
#
#
#  13.0
# 0 days 01:05:01.692000 laptime LAW 13.0 #
# 0 days 01:05:00.929000 previous laptime HAD 13.0
# 0 days 00:00:00.763000
# 0.763
#
#
#  13.0
# 0 days 01:05:03.109000 laptime BOR 13.0 #
# 0 days 01:05:01.692000 previous laptime LAW 13.0
# 0 days 00:00:01.417000
# 1.417
#
#
#  13.0
# 0 days 01:05:03.913000 laptime OCO 13.0 #
# 0 days 01:05:03.109000 previous laptime BOR 13.0
# 0 days 00:00:00.804000
# 0.804
#
#
#  13.0
# 0 days 01:05:04.472000 laptime DOO 13.0 #
# 0 days 01:05:03.913000 previous laptime OCO 13.0
# 0 days 00:00:00.559000
# 0.559
#
#
#  13.0
# 0 days 01:05:05.279000 laptime HUL 13.0 #
# 0 days 01:05:04.472000 previous laptime DOO 13.0
# 0 days 00:00:00.807000
# 0.807
#
#
#  13.0
# 0 days 01:05:23.032000 laptime SAI 13.0 #
# 0 days 01:05:05.279000 previous laptime HUL 13.0
# 0 days 00:00:17.753000
# 17.753
# adding gap 0 for first position
#
#
#  14.0
# 0 days 01:06:10.305000 laptime VER 14.0 #
# 0 days 01:06:08.421000 previous laptime HAM 14.0
# 0 days 00:00:01.884000
# 1.884
#
#
#  14.0
# 0 days 01:06:10.662000 laptime PIA 14.0 #
# 0 days 01:06:10.305000 previous laptime VER 14.0
# 0 days 00:00:00.357000
# 0.357
#
#
#  14.0
# 0 days 01:06:15.310000 laptime RUS 14.0 #
# 0 days 01:06:10.662000 previous laptime PIA 14.0
# 0 days 00:00:04.648000
# 4.648
#
#
#  14.0
# 0 days 01:06:18.964000 laptime LEC 14.0 #
# 0 days 01:06:15.310000 previous laptime RUS 14.0
# 0 days 00:00:03.654000
# 3.654
#
#
#  14.0
# 0 days 01:06:21.933000 laptime TSU 14.0 #
# 0 days 01:06:18.964000 previous laptime LEC 14.0
# 0 days 00:00:02.969000
# 2.969
#
#
#  14.0
# 0 days 01:06:22.575000 laptime ANT 14.0 #
# 0 days 01:06:21.933000 previous laptime TSU 14.0
# 0 days 00:00:00.642000
# 0.642
#
#
#  14.0
# 0 days 01:06:23.422000 laptime STR 14.0 #
# 0 days 01:06:22.575000 previous laptime ANT 14.0
# 0 days 00:00:00.847000
# 0.847
#
#
#  14.0
# 0 days 01:06:25.648000 laptime NOR 14.0 #
# 0 days 01:06:23.422000 previous laptime STR 14.0
# 0 days 00:00:02.226000
# 2.226
#
#
#  14.0
# 0 days 01:06:31.016000 laptime ALO 14.0 #
# 0 days 01:06:25.648000 previous laptime NOR 14.0
# 0 days 00:00:05.368000
# 5.368
#
#
#  14.0
# 0 days 01:06:32.874000 laptime ALB 14.0 #
# 0 days 01:06:31.016000 previous laptime ALO 14.0
# 0 days 00:00:01.858000
# 1.858
#
#
#  14.0
# 0 days 01:06:35.413000 laptime BEA 14.0 #
# 0 days 01:06:32.874000 previous laptime ALB 14.0
# 0 days 00:00:02.539000
# 2.539
#
#
#  14.0
# 0 days 01:06:39.099000 laptime GAS 14.0 #
# 0 days 01:06:35.413000 previous laptime BEA 14.0
# 0 days 00:00:03.686000
# 3.686
#
#
#  14.0
# 0 days 01:06:39.573000 laptime HAD 14.0 #
# 0 days 01:06:39.099000 previous laptime GAS 14.0
# 0 days 00:00:00.474000
# 0.474
#
#
#  14.0
# 0 days 01:06:40.187000 laptime LAW 14.0 #
# 0 days 01:06:39.573000 previous laptime HAD 14.0
# 0 days 00:00:00.614000
# 0.614
#
#
#  14.0
# 0 days 01:06:42.034000 laptime BOR 14.0 #
# 0 days 01:06:40.187000 previous laptime LAW 14.0
# 0 days 00:00:01.847000
# 1.847
#
#
#  14.0
# 0 days 01:06:42.784000 laptime OCO 14.0 #
# 0 days 01:06:42.034000 previous laptime BOR 14.0
# 0 days 00:00:00.750000
# 0.75
#
#
#  14.0
# 0 days 01:06:43.987000 laptime DOO 14.0 #
# 0 days 01:06:42.784000 previous laptime OCO 14.0
# 0 days 00:00:01.203000
# 1.203
#
#
#  14.0
# 0 days 01:06:44.470000 laptime HUL 14.0 #
# 0 days 01:06:43.987000 previous laptime DOO 14.0
# 0 days 00:00:00.483000
# 0.483
#
#
#  14.0
# 0 days 01:06:58.851000 laptime SAI 14.0 #
# 0 days 01:06:44.470000 previous laptime HUL 14.0
# 0 days 00:00:14.381000
# 14.381
# adding gap 0 for first position
#
#
#  15.0
# 0 days 01:07:48.514000 laptime PIA 15.0 #
# 0 days 01:07:45.928000 previous laptime HAM 15.0
# 0 days 00:00:02.586000
# 2.586
#
#
#  15.0
# 0 days 01:07:48.028000 laptime VER 15.0 #
# 0 days 01:07:48.514000 previous laptime PIA 15.0
# -1 days +23:59:59.514000
# -0.486
#
#
#  15.0
# 0 days 01:07:53.351000 laptime RUS 15.0 #
# 0 days 01:07:48.028000 previous laptime VER 15.0
# 0 days 00:00:05.323000
# 5.323
#
#
#  15.0
# 0 days 01:07:56.231000 laptime LEC 15.0 #
# 0 days 01:07:53.351000 previous laptime RUS 15.0
# 0 days 00:00:02.880000
# 2.88
#
#
#  15.0
# 0 days 01:08:00.572000 laptime TSU 15.0 #
# 0 days 01:07:56.231000 previous laptime LEC 15.0
# 0 days 00:00:04.341000
# 4.341
#
#
#  15.0
# 0 days 01:08:01.171000 laptime ANT 15.0 #
# 0 days 01:08:00.572000 previous laptime TSU 15.0
# 0 days 00:00:00.599000
# 0.599
#
#
#  15.0
# 0 days 01:08:02.398000 laptime STR 15.0 #
# 0 days 01:08:01.171000 previous laptime ANT 15.0
# 0 days 00:00:01.227000
# 1.227
#
#
#  15.0
# 0 days 01:08:03.561000 laptime NOR 15.0 #
# 0 days 01:08:02.398000 previous laptime STR 15.0
# 0 days 00:00:01.163000
# 1.163
#
#
#  15.0
# 0 days 01:08:10.618000 laptime ALO 15.0 #
# 0 days 01:08:03.561000 previous laptime NOR 15.0
# 0 days 00:00:07.057000
# 7.057
#
#
#  15.0
# 0 days 01:08:12.318000 laptime ALB 15.0 #
# 0 days 01:08:10.618000 previous laptime ALO 15.0
# 0 days 00:00:01.700000
# 1.7
#
#
#  15.0
# 0 days 01:08:15.542000 laptime BEA 15.0 #
# 0 days 01:08:12.318000 previous laptime ALB 15.0
# 0 days 00:00:03.224000
# 3.224
#
#
#  15.0
# 0 days 01:08:18.283000 laptime GAS 15.0 #
# 0 days 01:08:15.542000 previous laptime BEA 15.0
# 0 days 00:00:02.741000
# 2.741
#
#
#  15.0
# 0 days 01:08:18.667000 laptime HAD 15.0 #
# 0 days 01:08:18.283000 previous laptime GAS 15.0
# 0 days 00:00:00.384000
# 0.384
#
#
#  15.0
# 0 days 01:08:19.588000 laptime LAW 15.0 #
# 0 days 01:08:18.667000 previous laptime HAD 15.0
# 0 days 00:00:00.921000
# 0.921
#
#
#  15.0
# 0 days 01:08:21.224000 laptime BOR 15.0 #
# 0 days 01:08:19.588000 previous laptime LAW 15.0
# 0 days 00:00:01.636000
# 1.6360000000000001
#
#
#  15.0
# 0 days 01:08:21.964000 laptime OCO 15.0 #
# 0 days 01:08:21.224000 previous laptime BOR 15.0
# 0 days 00:00:00.740000
# 0.74
#
#
#  15.0
# 0 days 01:08:24.337000 laptime HUL 15.0 #
# 0 days 01:08:21.964000 previous laptime OCO 15.0
# 0 days 00:00:02.373000
# 2.373
#
#
#  15.0
# 0 days 01:08:23.939000 laptime DOO 15.0 #
# 0 days 01:08:24.337000 previous laptime HUL 15.0
# -1 days +23:59:59.602000
# -0.398
#
#
#  15.0
# 0 days 01:08:35.453000 laptime SAI 15.0 #
# 0 days 01:08:23.939000 previous laptime DOO 15.0
# 0 days 00:00:11.514000
# 11.514
# adding gap 0 for first position
#
#
#  16.0
# 0 days 01:09:26.631000 laptime PIA 16.0 #
# 0 days 01:09:23.958000 previous laptime HAM 16.0
# 0 days 00:00:02.673000
# 2.673
#
#
#  16.0
# 0 days 01:09:27.200000 laptime VER 16.0 #
# 0 days 01:09:26.631000 previous laptime PIA 16.0
# 0 days 00:00:00.569000
# 0.569
#
#
#  16.0
# 0 days 01:09:31.655000 laptime RUS 16.0 #
# 0 days 01:09:27.200000 previous laptime VER 16.0
# 0 days 00:00:04.455000
# 4.455
#
#
#  16.0
# 0 days 01:09:33.526000 laptime LEC 16.0 #
# 0 days 01:09:31.655000 previous laptime RUS 16.0
# 0 days 00:00:01.871000
# 1.871
#
#
#  16.0
# 0 days 01:09:39.665000 laptime TSU 16.0 #
# 0 days 01:09:33.526000 previous laptime LEC 16.0
# 0 days 00:00:06.139000
# 6.139
#
#
#  16.0
# 0 days 01:09:40.166000 laptime ANT 16.0 #
# 0 days 01:09:39.665000 previous laptime TSU 16.0
# 0 days 00:00:00.501000
# 0.501
#
#
#  16.0
# 0 days 01:09:41.903000 laptime STR 16.0 #
# 0 days 01:09:40.166000 previous laptime ANT 16.0
# 0 days 00:00:01.737000
# 1.737
#
#
#  16.0
# 0 days 01:09:42.545000 laptime NOR 16.0 #
# 0 days 01:09:41.903000 previous laptime STR 16.0
# 0 days 00:00:00.642000
# 0.642
#
#
#  16.0
# 0 days 01:09:50.994000 laptime ALO 16.0 #
# 0 days 01:09:42.545000 previous laptime NOR 16.0
# 0 days 00:00:08.449000
# 8.449
#
#
#  16.0
# 0 days 01:09:52.159000 laptime ALB 16.0 #
# 0 days 01:09:50.994000 previous laptime ALO 16.0
# 0 days 00:00:01.165000
# 1.165
#
#
#  16.0
# 0 days 01:09:56.064000 laptime BEA 16.0 #
# 0 days 01:09:52.159000 previous laptime ALB 16.0
# 0 days 00:00:03.905000
# 3.9050000000000002
#
#
#  16.0
# 0 days 01:09:57.126000 laptime GAS 16.0 #
# 0 days 01:09:56.064000 previous laptime BEA 16.0
# 0 days 00:00:01.062000
# 1.062
#
#
#  16.0
# 0 days 01:09:57.810000 laptime HAD 16.0 #
# 0 days 01:09:57.126000 previous laptime GAS 16.0
# 0 days 00:00:00.684000
# 0.684
#
#
#  16.0
# 0 days 01:09:58.729000 laptime LAW 16.0 #
# 0 days 01:09:57.810000 previous laptime HAD 16.0
# 0 days 00:00:00.919000
# 0.919
#
#
#  16.0
# 0 days 01:10:00.755000 laptime BOR 16.0 #
# 0 days 01:09:58.729000 previous laptime LAW 16.0
# 0 days 00:00:02.026000
# 2.026
#
#
#  16.0
# 0 days 01:10:01.418000 laptime OCO 16.0 #
# 0 days 01:10:00.755000 previous laptime BOR 16.0
# 0 days 00:00:00.663000
# 0.663
#
#
#  16.0
# 0 days 01:10:03.755000 laptime HUL 16.0 #
# 0 days 01:10:01.418000 previous laptime OCO 16.0
# 0 days 00:00:02.337000
# 2.337
#
#
#  16.0
# 0 days 01:10:04.743000 laptime DOO 16.0 #
# 0 days 01:10:03.755000 previous laptime HUL 16.0
# 0 days 00:00:00.988000
# 0.988
#
#
#  16.0
# 0 days 01:10:12.808000 laptime SAI 16.0 #
# 0 days 01:10:04.743000 previous laptime DOO 16.0
# 0 days 00:00:08.065000
# 8.065
# adding gap 0 for first position
#
#
#  17.0
# 0 days 01:11:05.372000 laptime PIA 17.0 #
# 0 days 01:11:01.587000 previous laptime HAM 17.0
# 0 days 00:00:03.785000
# 3.785
#
#
#  17.0
# 0 days 01:11:06.825000 laptime VER 17.0 #
# 0 days 01:11:05.372000 previous laptime PIA 17.0
# 0 days 00:00:01.453000
# 1.453
#
#
#  17.0
# 0 days 01:11:09.738000 laptime RUS 17.0 #
# 0 days 01:11:06.825000 previous laptime VER 17.0
# 0 days 00:00:02.913000
# 2.9130000000000003
#
#
#  17.0
# 0 days 01:11:11.159000 laptime LEC 17.0 #
# 0 days 01:11:09.738000 previous laptime RUS 17.0
# 0 days 00:00:01.421000
# 1.421
#
#
#  17.0
# 0 days 01:11:18.591000 laptime TSU 17.0 #
# 0 days 01:11:11.159000 previous laptime LEC 17.0
# 0 days 00:00:07.432000
# 7.432
#
#
#  17.0
# 0 days 01:11:19.107000 laptime ANT 17.0 #
# 0 days 01:11:18.591000 previous laptime TSU 17.0
# 0 days 00:00:00.516000
# 0.516
#
#
#  17.0
# 0 days 01:11:21.307000 laptime NOR 17.0 #
# 0 days 01:11:19.107000 previous laptime ANT 17.0
# 0 days 00:00:02.200000
# 2.2
#
#
#  17.0
# 0 days 01:11:20.581000 laptime STR 17.0 #
# 0 days 01:11:21.307000 previous laptime NOR 17.0
# -1 days +23:59:59.274000
# -0.726
#
#
#  17.0
# 0 days 01:11:31.053000 laptime ALO 17.0 #
# 0 days 01:11:20.581000 previous laptime STR 17.0
# 0 days 00:00:10.472000
# 10.472
#
#
#  17.0
# 0 days 01:11:32.268000 laptime ALB 17.0 #
# 0 days 01:11:31.053000 previous laptime ALO 17.0
# 0 days 00:00:01.215000
# 1.215
#
#
#  17.0
# 0 days 01:11:36.771000 laptime GAS 17.0 #
# 0 days 01:11:32.268000 previous laptime ALB 17.0
# 0 days 00:00:04.503000
# 4.503
#
#
#  17.0
# 0 days 01:11:36.278000 laptime BEA 17.0 #
# 0 days 01:11:36.771000 previous laptime GAS 17.0
# -1 days +23:59:59.507000
# -0.493
#
#
#  17.0
# 0 days 01:11:37.344000 laptime HAD 17.0 #
# 0 days 01:11:36.278000 previous laptime BEA 17.0
# 0 days 00:00:01.066000
# 1.066
#
#
#  17.0
# 0 days 01:11:38.226000 laptime LAW 17.0 #
# 0 days 01:11:37.344000 previous laptime HAD 17.0
# 0 days 00:00:00.882000
# 0.882
#
#
#  17.0
# 0 days 01:11:39.881000 laptime BOR 17.0 #
# 0 days 01:11:38.226000 previous laptime LAW 17.0
# 0 days 00:00:01.655000
# 1.655
#
#
#  17.0
# 0 days 01:11:40.644000 laptime OCO 17.0 #
# 0 days 01:11:39.881000 previous laptime BOR 17.0
# 0 days 00:00:00.763000
# 0.763
#
#
#  17.0
# 0 days 01:11:42.352000 laptime HUL 17.0 #
# 0 days 01:11:40.644000 previous laptime OCO 17.0
# 0 days 00:00:01.708000
# 1.708
#
#
#  17.0
# 0 days 01:11:43.352000 laptime DOO 17.0 #
# 0 days 01:11:42.352000 previous laptime HUL 17.0
# 0 days 00:00:01
# 1.0
#
#
#  17.0
# 0 days 01:11:50.117000 laptime SAI 17.0 #
# 0 days 01:11:43.352000 previous laptime DOO 17.0
# 0 days 00:00:06.765000
# 6.765
# adding gap 0 for first position
#
#
#  18.0
# 0 days 01:12:44.120000 laptime PIA 18.0 #
# 0 days 01:12:39.198000 previous laptime HAM 18.0
# 0 days 00:00:04.922000
# 4.922
#
#
#  18.0
# 0 days 01:12:45.988000 laptime VER 18.0 #
# 0 days 01:12:44.120000 previous laptime PIA 18.0
# 0 days 00:00:01.868000
# 1.8679999999999999
#
#
#  18.0
# 0 days 01:12:47.924000 laptime RUS 18.0 #
# 0 days 01:12:45.988000 previous laptime VER 18.0
# 0 days 00:00:01.936000
# 1.936
#
#
#  18.0
# 0 days 01:12:48.499000 laptime LEC 18.0 #
# 0 days 01:12:47.924000 previous laptime RUS 18.0
# 0 days 00:00:00.575000
# 0.575
#
#
#  18.0
# 0 days 01:12:57.629000 laptime TSU 18.0 #
# 0 days 01:12:48.499000 previous laptime LEC 18.0
# 0 days 00:00:09.130000
# 9.13
#
#
#  18.0
# 0 days 01:12:58.385000 laptime ANT 18.0 #
# 0 days 01:12:57.629000 previous laptime TSU 18.0
# 0 days 00:00:00.756000
# 0.756
#
#
#  18.0
# 0 days 01:13:00.029000 laptime NOR 18.0 #
# 0 days 01:12:58.385000 previous laptime ANT 18.0
# 0 days 00:00:01.644000
# 1.6440000000000001
#
#
#  18.0
# 0 days 01:13:00.644000 laptime STR 18.0 #
# 0 days 01:13:00.029000 previous laptime NOR 18.0
# 0 days 00:00:00.615000
# 0.615
#
#
#  18.0
# 0 days 01:13:11.125000 laptime ALO 18.0 #
# 0 days 01:13:00.644000 previous laptime STR 18.0
# 0 days 00:00:10.481000
# 10.481
#
#
#  18.0
# 0 days 01:13:12.340000 laptime ALB 18.0 #
# 0 days 01:13:11.125000 previous laptime ALO 18.0
# 0 days 00:00:01.215000
# 1.215
#
#
#  18.0
# 0 days 01:13:15.947000 laptime GAS 18.0 #
# 0 days 01:13:12.340000 previous laptime ALB 18.0
# 0 days 00:00:03.607000
# 3.607
#
#
#  18.0
# 0 days 01:13:18.071000 laptime HAD 18.0 #
# 0 days 01:13:15.947000 previous laptime GAS 18.0
# 0 days 00:00:02.124000
# 2.124
#
#
#  18.0
# 0 days 01:13:17.593000 laptime BEA 18.0 #
# 0 days 01:13:18.071000 previous laptime HAD 18.0
# -1 days +23:59:59.522000
# -0.478
#
#
#  18.0
# 0 days 01:13:18.525000 laptime LAW 18.0 #
# 0 days 01:13:17.593000 previous laptime BEA 18.0
# 0 days 00:00:00.932000
# 0.932
#
#
#  18.0
# 0 days 01:13:19.683000 laptime BOR 18.0 #
# 0 days 01:13:18.525000 previous laptime LAW 18.0
# 0 days 00:00:01.158000
# 1.158
#
#
#  18.0
# 0 days 01:13:20.209000 laptime OCO 18.0 #
# 0 days 01:13:19.683000 previous laptime BOR 18.0
# 0 days 00:00:00.526000
# 0.526
#
#
#  18.0
# 0 days 01:13:21.997000 laptime DOO 18.0 #
# 0 days 01:13:20.209000 previous laptime OCO 18.0
# 0 days 00:00:01.788000
# 1.788
#
#
#  18.0
# 0 days 01:13:21.690000 laptime HUL 18.0 #
# 0 days 01:13:21.997000 previous laptime DOO 18.0
# -1 days +23:59:59.693000
# -0.30700000000000005
#
#
#  18.0
# 0 days 01:13:27.959000 laptime SAI 18.0 #
# 0 days 01:13:21.690000 previous laptime HUL 18.0
# 0 days 00:00:06.269000
# 6.269
# adding gap 0 for first position
#
#
#  19.0
# 0 days 01:14:22.732000 laptime PIA 19.0 #
# 0 days 01:14:16.547000 previous laptime HAM 19.0
# 0 days 00:00:06.185000
# 6.185
#
#
#  19.0
# 0 days 01:14:25.090000 laptime VER 19.0 #
# 0 days 01:14:22.732000 previous laptime PIA 19.0
# 0 days 00:00:02.358000
# 2.358
#
#
#  19.0
# 0 days 01:14:26.237000 laptime RUS 19.0 #
# 0 days 01:14:25.090000 previous laptime VER 19.0
# 0 days 00:00:01.147000
# 1.147
#
#
#  19.0
# 0 days 01:14:26.783000 laptime LEC 19.0 #
# 0 days 01:14:26.237000 previous laptime RUS 19.0
# 0 days 00:00:00.546000
# 0.546
#
#
#  19.0
# 0 days 01:14:36.973000 laptime TSU 19.0 #
# 0 days 01:14:26.783000 previous laptime LEC 19.0
# 0 days 00:00:10.190000
# 10.19
#
#
#  19.0
# 0 days 01:14:37.468000 laptime ANT 19.0 #
# 0 days 01:14:36.973000 previous laptime TSU 19.0
# 0 days 00:00:00.495000
# 0.495
#
#
#  19.0
# 0 days 01:14:38.453000 laptime NOR 19.0 #
# 0 days 01:14:37.468000 previous laptime ANT 19.0
# 0 days 00:00:00.985000
# 0.985
#
#
#  19.0
# 0 days 01:14:39.710000 laptime STR 19.0 #
# 0 days 01:14:38.453000 previous laptime NOR 19.0
# 0 days 00:00:01.257000
# 1.2570000000000001
#
#
#  19.0
# 0 days 01:14:51.030000 laptime ALO 19.0 #
# 0 days 01:14:39.710000 previous laptime STR 19.0
# 0 days 00:00:11.320000
# 11.32
#
#
#  19.0
# 0 days 01:14:52.905000 laptime ALB 19.0 #
# 0 days 01:14:51.030000 previous laptime ALO 19.0
# 0 days 00:00:01.875000
# 1.875
#
#
#  19.0
# 0 days 01:14:54.303000 laptime GAS 19.0 #
# 0 days 01:14:52.905000 previous laptime ALB 19.0
# 0 days 00:00:01.398000
# 1.3980000000000001
#
#
#  19.0
# 0 days 01:14:57.603000 laptime HAD 19.0 #
# 0 days 01:14:54.303000 previous laptime GAS 19.0
# 0 days 00:00:03.300000
# 3.3
#
#
#  19.0
# 0 days 01:14:58.420000 laptime LAW 19.0 #
# 0 days 01:14:57.603000 previous laptime HAD 19.0
# 0 days 00:00:00.817000
# 0.817
#
#
#  19.0
# 0 days 01:14:58.104000 laptime BEA 19.0 #
# 0 days 01:14:58.420000 previous laptime LAW 19.0
# -1 days +23:59:59.684000
# -0.31599999999999995
#
#
#  19.0
# 0 days 01:14:59.945000 laptime OCO 19.0 #
# 0 days 01:14:58.104000 previous laptime BEA 19.0
# 0 days 00:00:01.841000
# 1.841
#
#
#  19.0
# 0 days 01:15:05.634000 laptime SAI 19.0 #
# 0 days 01:14:59.945000 previous laptime OCO 19.0
# 0 days 00:00:05.689000
# 5.689
#
#
#  19.0
# 0 days 01:14:59.325000 laptime BOR 19.0 #
# 0 days 01:15:05.634000 previous laptime SAI 19.0
# -1 days +23:59:53.691000
# -6.309
#
#
#  19.0
# 0 days 01:15:03.515000 laptime HUL 19.0 #
# 0 days 01:14:59.325000 previous laptime BOR 19.0
# 0 days 00:00:04.190000
# 4.19
#
#
#  19.0
# 0 days 01:15:01.655000 laptime DOO 19.0 #
# 0 days 01:15:03.515000 previous laptime HUL 19.0
# -1 days +23:59:58.140000
# -1.8599999999999999
#                       Time Driver DriverNumber LapTime  LapNumber  Stint  \
# 0   0 days 00:46:50.347000    HAM           44     NaT        1.0    1.0
# 38  0 days 00:46:51.118000    VER            1     NaT        1.0    1.0
# 19  0 days 00:46:52.437000    PIA           81     NaT        1.0    1.0
# 57  0 days 00:46:53.660000    RUS           63     NaT        1.0    1.0
# 76  0 days 00:46:54.007000    LEC           16     NaT        1.0    1.0
# 95  0 days 00:46:54.861000    TSU           22     NaT        1.0    1.0
# 114 0 days 00:46:55.209000    ANT           12     NaT        1.0    1.0
# 152 0 days 00:46:55.817000    STR           18     NaT        1.0    1.0
# 133 0 days 00:46:56.450000    NOR            4     NaT        1.0    1.0
# 171 0 days 00:46:57.003000    ALO           14     NaT        1.0    1.0
#
#     PitOutTime PitInTime Sector1Time            Sector2Time  ...  \
# 0          NaT       NaT         NaT 0 days 00:00:28.492000  ...
# 38         NaT       NaT         NaT 0 days 00:00:28.705000  ...
# 19         NaT       NaT         NaT 0 days 00:00:29.176000  ...
# 57         NaT       NaT         NaT 0 days 00:00:29.662000  ...
# 76         NaT       NaT         NaT 0 days 00:00:29.671000  ...
# 95         NaT       NaT         NaT 0 days 00:00:29.663000  ...
# 114        NaT       NaT         NaT 0 days 00:00:30.106000  ...
# 152        NaT       NaT         NaT 0 days 00:00:30.350000  ...
# 133        NaT       NaT         NaT 0 days 00:00:31.099000  ...
# 171        NaT       NaT         NaT 0 days 00:00:30.511000  ...
#
#                 Team           LapStartTime            LapStartDate  \
# 0            Ferrari 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 38   Red Bull Racing 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 19           McLaren 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 57          Mercedes 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 76           Ferrari 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 95      Racing Bulls 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 114         Mercedes 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 152     Aston Martin 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 133          McLaren 0 days 00:45:13.457000 2025-03-22 03:03:44.623
# 171     Aston Martin 0 days 00:45:13.457000 2025-03-22 03:03:44.623
#
#     TrackStatus  Position  Deleted  DeletedReason  FastF1Generated  \
# 0             1       1.0    False                           False
# 38            1       2.0    False                           False
# 19            1       3.0    False                           False
# 57            1       4.0    False                           False
# 76            1       5.0    False                           False
# 95            1       6.0    False                           False
# 114           1       7.0    False                           False
# 152           1       8.0    False                           False
# 133           1       9.0    False                           False
# 171           1      10.0    False                           False
#
#      IsAccurate GapInSeconds
# 0         False          0.0
# 38        False          0.0
# 19        False          0.0
# 57        False          0.0
# 76        False          0.0
# 95        False          0.0
# 114       False          0.0
# 152       False          0.0
# 133       False          0.0
# 171       False          0.0
#
# [10 rows x 32 columns]

# %%
#Extract useful variables
df_cs = sorted_china_sprint[['Team','Driver','DriverNumber','Position','Compound','LapTime','LapNumber','SpeedST','Stint','GapInSeconds']]
print(df_cs.shape)
#Delete first lap data
df_cs = df_cs[df_cs['LapTime'].isnull()==False]
print(df_cs.shape)
# Out:
# (380, 10)
# (360, 10)

# %%
#Compute lap time in seconds
df_cs['LapTimeInSeconds'] = df_cs['LapTime'].dt.total_seconds()
df_cs.sample(10)
# Out:
# /var/folders/88/94pqx5n57z5crmg3w50s99y00000gn/T/ipykernel_2018/1989071452.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cs['LapTimeInSeconds'] = df_cs['LapTime'].dt.total_seconds()
#                 Team Driver DriverNumber  Position Compound  \
# 105     Racing Bulls    TSU           22       6.0   MEDIUM
# 242     Racing Bulls    HAD            6      14.0   MEDIUM
# 263  Red Bull Racing    LAW           30      15.0   MEDIUM
# 199         Williams    ALB           23      11.0   MEDIUM
# 99      Racing Bulls    TSU           22       6.0   MEDIUM
# 229     Racing Bulls    HAD            6      16.0   MEDIUM
# 59          Mercedes    RUS           63       4.0   MEDIUM
# 29           McLaren    PIA           81       3.0   MEDIUM
# 141          McLaren    NOR            4       9.0   MEDIUM
# 47   Red Bull Racing    VER            1       2.0   MEDIUM
#
#                    LapTime  LapNumber  SpeedST  Stint  GapInSeconds  \
# 105 0 days 00:01:38.185000       11.0    314.0    1.0         2.074
# 242 0 days 00:01:39.143000       15.0    332.0    1.0         0.384
# 263 0 days 00:01:40.299000       17.0    340.0    1.0         0.882
# 199 0 days 00:01:38.292000       10.0    315.0    1.0         2.294
# 99  0 days 00:01:36.527000        5.0    334.0    1.0         1.078
# 229 0 days 00:01:38.139000        2.0    353.0    1.0         0.525
# 59  0 days 00:01:36.045000        3.0    314.0    1.0         1.569
# 29  0 days 00:01:36.851000       11.0    332.0    1.0         0.547
# 141 0 days 00:01:37.882000        9.0    314.0    1.0         1.964
# 47  0 days 00:01:37.050000       10.0    315.0    1.0         1.121
#
#      LapTimeInSeconds
# 105            98.185
# 242            99.143
# 263           100.299
# 199            98.292
# 99             96.527
# 229            98.139
# 59             96.045
# 29             96.851
# 141            97.882
# 47             97.050

# %% [markdown]
# <h3> Analyze Drivers' Race Pace

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df_cs,x='Driver',y='LapTimeInSeconds',hue='Driver',palette=driver_colors)
plt.legend(loc='upper right')
plt.title('Race Pace per Driver')
plt.ylabel('Lap Time [s]')
plt.xlabel('Driver')
# Out:
# /var/folders/88/94pqx5n57z5crmg3w50s99y00000gn/T/ipykernel_2018/1906527392.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='upper right')
# Text(0.5, 0, 'Driver')

# %% [markdown]
# <h3> Compare two drivers' race pace

# %%
plt.figure(figsize=(15,3))
sns.lineplot(data=df_cs[(df_cs['Driver']=='HAM')|(df_cs['Driver']=='VER')],x='LapNumber',y='LapTimeInSeconds',hue='Driver',palette=driver_colors)
plt.xticks(ticks=df_cs['LapNumber'].unique())
plt.yticks(np.arange(95,100,0.5))
plt.title('Pace comparison Ham vs Ver')
plt.ylabel('Lap Time [s]')
plt.xlabel('Lap')
plt.grid(color='grey')

# %%
plt.figure(figsize=(18,10))
sns.barplot(data=df_cs.groupby('Driver')['SpeedST'].max().sort_values(ascending=False),palette=driver_colors)
plt.ylim(315,358)
plt.yticks(np.arange(315,358,1),)
plt.annotate(text='No DRS for RUS nor HAM',xy=['VER',322],color='y')
plt.title('Max Speed Comparison per Driver')
plt.ylabel('Max Speed at longest straight [km/h]')
plt.xlabel('Driver')
plt.grid(color='grey')
# Out:
# /var/folders/88/94pqx5n57z5crmg3w50s99y00000gn/T/ipykernel_2018/1443305014.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_cs.groupby('Driver')['SpeedST'].max().sort_values(ascending=False),palette=driver_colors)

# %%
import utilities as ut

# %%
ut.top_speed_comparison_chart(df_cs)
# Out:
# /Users/dario/Documents/Python Stuff/F1/utilities.py:237: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=input_df.groupby('Driver')['SpeedST'].max().sort_values(ascending=False),palette=driver_colors)

# %% [markdown]
# <h3>Has Russell never in been in DRS zone either?

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df_cs[df_cs['Driver']=='RUS'],x='LapNumber',y='GapInSeconds',hue='Driver',palette=driver_colors,legend=False)
plt.xticks(df_cs['LapNumber'].unique())
plt.yticks(np.arange(0,6,0.2))
plt.title('Gap from previous driver trend for Russell')
plt.xlabel('Lap')
plt.ylabel('Gap [s]')
plt.plot([2,19],[1.0,1.0],linewidth=2,color='r')
plt.annotate(text='DRS Zone threshold',xy=[2,1.05],color='r')
plt.annotate(text='PIA overtakes VER',xy=[15.1,5.45],color='green')
plt.plot(15,5.41,marker='o',color='black')
plt.grid(color='grey')

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=df_cs,x='LapNumber',y='Position',hue='Driver',palette=driver_colors)
plt.yticks(np.arange(1,21,1))
plt.xticks(np.arange(1,20,1))
plt.gca().invert_yaxis()
plt.grid(color='grey')

# %%
df_cs[df_cs['LapNumber']==17]
# Out:
#                 Team Driver DriverNumber  Position Compound  \
# 16           Ferrari    HAM           44       1.0   MEDIUM
# 35           McLaren    PIA           81       2.0   MEDIUM
# 54   Red Bull Racing    VER            1       3.0   MEDIUM
# 73          Mercedes    RUS           63       4.0   MEDIUM
# 92           Ferrari    LEC           16       5.0   MEDIUM
# 111     Racing Bulls    TSU           22       6.0   MEDIUM
# 130         Mercedes    ANT           12       7.0   MEDIUM
# 149          McLaren    NOR            4       8.0   MEDIUM
# 168     Aston Martin    STR           18       9.0   MEDIUM
# 187     Aston Martin    ALO           14      10.0   MEDIUM
# 206         Williams    ALB           23      11.0   MEDIUM
# 225           Alpine    GAS           10      12.0   MEDIUM
# 282     Haas F1 Team    BEA           87      13.0   MEDIUM
# 244     Racing Bulls    HAD            6      14.0   MEDIUM
# 263  Red Bull Racing    LAW           30      15.0   MEDIUM
# 339      Kick Sauber    BOR            5      16.0   MEDIUM
# 301     Haas F1 Team    OCO           31      17.0   MEDIUM
# 358      Kick Sauber    HUL           27      18.0   MEDIUM
# 377           Alpine    DOO            7      19.0   MEDIUM
# 320         Williams    SAI           55      20.0   MEDIUM
#
#                    LapTime  LapNumber  SpeedST  Stint  GapInSeconds  \
# 16  0 days 00:01:37.611000       17.0    314.0    1.0         0.000
# 35  0 days 00:01:38.748000       17.0    312.0    1.0         3.785
# 54  0 days 00:01:39.163000       17.0    313.0    1.0         1.453
# 73  0 days 00:01:38.186000       17.0    315.0    1.0         2.913
# 92  0 days 00:01:37.340000       17.0    332.0    1.0         1.421
# 111 0 days 00:01:39.038000       17.0    313.0    1.0         7.432
# 130 0 days 00:01:39.278000       17.0    332.0    1.0         0.516
# 149 0 days 00:01:38.722000       17.0    337.0    1.0         2.200
# 168 0 days 00:01:40.063000       17.0    312.0    1.0        -0.726
# 187 0 days 00:01:40.072000       17.0    312.0    1.0        10.472
# 206 0 days 00:01:40.072000       17.0    316.0    1.0         1.215
# 225 0 days 00:01:39.176000       17.0    305.0    1.0         4.503
# 282 0 days 00:01:41.315000       17.0    313.0    1.0        -0.493
# 244 0 days 00:01:40.727000       17.0    335.0    1.0         1.066
# 263 0 days 00:01:40.299000       17.0    340.0    1.0         0.882
# 339 0 days 00:01:39.802000       17.0    315.0    1.0         1.655
# 301 0 days 00:01:39.565000       17.0    329.0    1.0         0.763
# 358 0 days 00:01:39.338000       17.0    308.0    1.0         1.708
# 377 0 days 00:01:38.645000       17.0    327.0    1.0         1.000
# 320 0 days 00:01:37.842000       17.0    314.0    2.0         6.765
#
#      LapTimeInSeconds
# 16             97.611
# 35             98.748
# 54             99.163
# 73             98.186
# 92             97.340
# 111            99.038
# 130            99.278
# 149            98.722
# 168           100.063
# 187           100.072
# 206           100.072
# 225            99.176
# 282           101.315
# 244           100.727
# 263           100.299
# 339            99.802
# 301            99.565
# 358            99.338
# 377            98.645
# 320            97.842

# %% [markdown]
# # China Shootout Quali

# %%
china_shootout_quali = fastf1.get_session(2025,'China','Sprint Qualifying')
china_shootout_quali.load()
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Sprint Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# core        WARNING 	Sprint Qualifying is not supported by Ergast! Limited results are calculated from timing data.
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '1', '81', '16', '63', '4', '12', '22', '23', '18', '14', '87', '55', '5', '6', '7', '10', '31', '27', '30']

# %%
sq_df = china_shootout_quali.laps

# %%
sq_df.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:16:57.349000    NOR            4                    NaT
# 1 0 days 00:18:29.597000    NOR            4 0 days 00:01:32.248000
# 2 0 days 00:20:32.738000    NOR            4 0 days 00:02:03.141000
# 3 0 days 00:22:38.639000    NOR            4 0 days 00:02:05.901000
# 4 0 days 00:24:10.035000    NOR            4 0 days 00:01:31.396000
#
#    LapNumber  Stint             PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0 0 days 00:14:48.482000       NaT                    NaT
# 1        2.0    1.0                    NaT       NaT 0 days 00:00:24.618000
# 2        3.0    1.0                    NaT       NaT 0 days 00:00:34.193000
# 3        4.0    1.0                    NaT       NaT 0 days 00:00:38.528000
# 4        5.0    1.0                    NaT       NaT 0 days 00:00:24.207000
#
#              Sector2Time  ... FreshTyre     Team           LapStartTime  \
# 0 0 days 00:00:35.498000  ...      True  McLaren 0 days 00:14:48.482000
# 1 0 days 00:00:27.789000  ...      True  McLaren 0 days 00:16:57.349000
# 2 0 days 00:00:38.202000  ...      True  McLaren 0 days 00:18:29.597000
# 3 0 days 00:00:35.518000  ...      True  McLaren 0 days 00:20:32.738000
# 4 0 days 00:00:27.555000  ...      True  McLaren 0 days 00:22:38.639000
#
#              LapStartDate  TrackStatus  Position  Deleted  DeletedReason  \
# 0 2025-03-21 07:32:20.802            1       NaN    False
# 1 2025-03-21 07:34:29.669            1       NaN    False
# 2 2025-03-21 07:36:01.917            1       NaN    False
# 3 2025-03-21 07:38:05.058            1       NaN    False
# 4 2025-03-21 07:40:10.959            1       NaN    False
#
#    FastF1Generated IsAccurate
# 0            False      False
# 1            False       True
# 2            False       True
# 3            False       True
# 4            False       True
#
# [5 rows x 31 columns]

# %%
drivers = sq_df['Driver'].unique()
drivers
# Out:
# array(['NOR', 'LEC', 'PIA', 'HAM', 'RUS', 'HUL', 'ALB', 'ALO', 'ANT',
#        'TSU', 'BEA', 'STR', 'OCO', 'GAS', 'SAI', 'VER', 'HAD', 'LAW',
#        'BOR', 'DOO'], dtype=object)

# %%
fastest_laps = []
for driver in drivers:
    fastest_lap_dr = sq_df.pick_drivers(driver).pick_fastest()
    fastest_laps.append(fastest_lap_dr)

fastest_laps = Laps(fastest_laps)

# %%
pole_lap = fastest_laps.pick_fastest()
pole_lap
# Out:
# Time                      0 days 00:55:30.837000
# Driver                                       HAM
# DriverNumber                                  44
# LapTime                   0 days 00:01:30.849000
# LapNumber                                   14.0
# Stint                                        4.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:24.261000
# Sector2Time               0 days 00:00:27.249000
# Sector3Time               0 days 00:00:39.339000
# Sector1SessionTime        0 days 00:54:24.249000
# Sector2SessionTime        0 days 00:54:51.498000
# Sector3SessionTime        0 days 00:55:30.837000
# SpeedI1                                    283.0
# SpeedI2                                    278.0
# SpeedFL                                    270.0
# SpeedST                                    335.0
# IsPersonalBest                              True
# Compound                                    SOFT
# TyreLife                                     2.0
# FreshTyre                                   True
# Team                                     Ferrari
# LapStartTime              0 days 00:53:59.988000
# LapStartDate          2025-03-21 08:11:32.308000
# TrackStatus                                    1
# Position                                     NaN
# Deleted                                    False
# DeletedReason
# FastF1Generated                            False
# IsAccurate                                  True
# Name: 54, dtype: object

# %%
fastest_laps['LapTimeDelta'] = fastest_laps['LapTime'] - pole_lap['LapTime']

# %%
fastest_laps['Delta in seconds'] = fastest_laps['LapTimeDelta'].dt.total_seconds()

# %%
fastest_laps.sort_values('Delta in seconds',inplace=True)
fastest_laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 54  0 days 00:55:30.837000    HAM           44 0 days 00:01:30.849000
# 184 0 days 00:56:57.327000    VER            1 0 days 00:01:30.867000
# 37  0 days 00:52:08.349000    PIA           81 0 days 00:01:30.929000
# 26  0 days 00:55:40.416000    LEC           16 0 days 00:01:31.057000
# 72  0 days 00:52:30.660000    RUS           63 0 days 00:01:31.169000
# 7   0 days 00:35:27.451000    NOR            4 0 days 00:01:31.174000
# 114 0 days 00:42:34.197000    ANT           12 0 days 00:01:31.475000
# 88  0 days 00:42:11.439000    ALB           23 0 days 00:01:31.539000
# 147 0 days 00:41:26.963000    STR           18 0 days 00:01:31.742000
# 129 0 days 00:57:36.324000    TSU           22 0 days 00:01:31.773000
# 100 0 days 00:41:47.174000    ALO           14 0 days 00:01:31.815000
# 138 0 days 00:41:52.608000    BEA           87 0 days 00:01:31.978000
# 190 0 days 00:24:27.589000    HAD            6 0 days 00:01:32.171000
# 172 0 days 00:42:01.100000    SAI           55 0 days 00:01:32.325000
# 203 0 days 00:24:48.621000    BOR            5 0 days 00:01:32.539000
# 215 0 days 00:22:47.676000    DOO            7 0 days 00:01:32.575000
# 162 0 days 00:22:41.825000    GAS           10 0 days 00:01:32.640000
# 156 0 days 00:25:50.645000    OCO           31 0 days 00:01:32.651000
# 75  0 days 00:19:04.971000    HUL           27 0 days 00:01:32.675000
# 195 0 days 00:18:13.068000    LAW           30 0 days 00:01:32.729000
#
#      LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 54        14.0    4.0        NaT       NaT 0 days 00:00:24.261000
# 184       11.0    4.0        NaT       NaT 0 days 00:00:24.269000
# 37        10.0    3.0        NaT       NaT 0 days 00:00:24.297000
# 26        14.0    4.0        NaT       NaT 0 days 00:00:24.322000
# 72        17.0    3.0        NaT       NaT 0 days 00:00:24.302000
# 7          8.0    2.0        NaT       NaT 0 days 00:00:24.278000
# 114       13.0    3.0        NaT       NaT 0 days 00:00:24.488000
# 88         9.0    2.0        NaT       NaT 0 days 00:00:24.321000
# 147        8.0    2.0        NaT       NaT 0 days 00:00:24.390000
# 129       11.0    4.0        NaT       NaT 0 days 00:00:24.350000
# 100        7.0    2.0        NaT       NaT 0 days 00:00:24.392000
# 138        8.0    3.0        NaT       NaT 0 days 00:00:24.538000
# 190        5.0    2.0        NaT       NaT 0 days 00:00:24.657000
# 172        9.0    3.0        NaT       NaT 0 days 00:00:24.615000
# 203        5.0    2.0        NaT       NaT 0 days 00:00:24.608000
# 215        5.0    1.0        NaT       NaT 0 days 00:00:24.609000
# 162        5.0    1.0        NaT       NaT 0 days 00:00:24.918000
# 156        5.0    2.0        NaT       NaT 0 days 00:00:24.702000
# 75         2.0    1.0        NaT       NaT 0 days 00:00:24.606000
# 195        2.0    1.0        NaT       NaT 0 days 00:00:24.780000
#
#                Sector2Time  ...           LapStartTime  \
# 54  0 days 00:00:27.249000  ... 0 days 00:53:59.988000
# 184 0 days 00:00:27.361000  ... 0 days 00:55:26.460000
# 37  0 days 00:00:27.317000  ... 0 days 00:50:37.420000
# 26  0 days 00:00:27.384000  ... 0 days 00:54:09.359000
# 72  0 days 00:00:27.425000  ... 0 days 00:50:59.491000
# 7   0 days 00:00:27.499000  ... 0 days 00:33:56.277000
# 114 0 days 00:00:27.522000  ... 0 days 00:41:02.722000
# 88  0 days 00:00:27.612000  ... 0 days 00:40:39.900000
# 147 0 days 00:00:27.499000  ... 0 days 00:39:55.221000
# 129 0 days 00:00:27.627000  ... 0 days 00:56:04.551000
# 100 0 days 00:00:27.612000  ... 0 days 00:40:15.359000
# 138 0 days 00:00:27.522000  ... 0 days 00:40:20.630000
# 190 0 days 00:00:27.677000  ... 0 days 00:22:55.418000
# 172 0 days 00:00:27.668000  ... 0 days 00:40:28.775000
# 203 0 days 00:00:27.854000  ... 0 days 00:23:16.082000
# 215 0 days 00:00:27.945000  ... 0 days 00:21:15.101000
# 162 0 days 00:00:27.828000  ... 0 days 00:21:09.185000
# 156 0 days 00:00:27.798000  ... 0 days 00:24:17.994000
# 75  0 days 00:00:27.906000  ... 0 days 00:17:32.296000
# 195 0 days 00:00:27.669000  ... 0 days 00:16:40.339000
#
#                LapStartDate TrackStatus Position  Deleted  DeletedReason  \
# 54  2025-03-21 08:11:32.308           1      NaN    False
# 184 2025-03-21 08:12:58.780           1      NaN    False
# 37  2025-03-21 08:08:09.740           1      NaN    False
# 26  2025-03-21 08:11:41.679           1      NaN    False
# 72  2025-03-21 08:08:31.811           1      NaN    False
# 7   2025-03-21 07:51:28.597           1      NaN    False
# 114 2025-03-21 07:58:35.042           1      NaN    False
# 88  2025-03-21 07:58:12.220           1      NaN    False
# 147 2025-03-21 07:57:27.541           1      NaN    False
# 129 2025-03-21 08:13:36.871           1      NaN    False
# 100 2025-03-21 07:57:47.679           1      NaN    False
# 138 2025-03-21 07:57:52.950           1      NaN    False
# 190 2025-03-21 07:40:27.738           1      NaN    False
# 172 2025-03-21 07:58:01.095           1      NaN    False
# 203 2025-03-21 07:40:48.402           1      NaN    False
# 215 2025-03-21 07:38:47.421           1      NaN    False
# 162 2025-03-21 07:38:41.505           1      NaN    False
# 156 2025-03-21 07:41:50.314           1      NaN    False
# 75  2025-03-21 07:35:04.616           1      NaN    False
# 195 2025-03-21 07:34:12.659           1      NaN    False
#
#      FastF1Generated  IsAccurate           LapTimeDelta Delta in seconds
# 54             False        True        0 days 00:00:00            0.000
# 184            False        True 0 days 00:00:00.018000            0.018
# 37             False        True 0 days 00:00:00.080000            0.080
# 26             False        True 0 days 00:00:00.208000            0.208
# 72             False        True 0 days 00:00:00.320000            0.320
# 7              False        True 0 days 00:00:00.325000            0.325
# 114            False        True 0 days 00:00:00.626000            0.626
# 88             False        True 0 days 00:00:00.690000            0.690
# 147            False        True 0 days 00:00:00.893000            0.893
# 129            False        True 0 days 00:00:00.924000            0.924
# 100            False        True 0 days 00:00:00.966000            0.966
# 138            False        True 0 days 00:00:01.129000            1.129
# 190            False        True 0 days 00:00:01.322000            1.322
# 172            False        True 0 days 00:00:01.476000            1.476
# 203            False        True 0 days 00:00:01.690000            1.690
# 215            False        True 0 days 00:00:01.726000            1.726
# 162            False        True 0 days 00:00:01.791000            1.791
# 156            False        True 0 days 00:00:01.802000            1.802
# 75             False        True 0 days 00:00:01.826000            1.826
# 195            False        True 0 days 00:00:01.880000            1.880
#
# [20 rows x 33 columns]

# %%
fastest_laps.reset_index(inplace=True)
fastest_laps.drop(columns=['index'],inplace=True)

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(orient='horizontal',data=fastest_laps.head(10),x='Delta in seconds',y='Driver',hue='Driver',palette=driver_colors)
plt.title('Delta from Pole Position - Shootout Qualifying')
plt.ylabel('Driver')
plt.xlabel('Delta [s]')
plt.xticks(np.arange(fastest_laps['Delta in seconds'].min(),fastest_laps['Delta in seconds'].max(),0.1))
custom_y_ticks_labels = [f'{team} {drv}' for team, drv, in zip(fastest_laps['Team'],fastest_laps['Driver'])]
ax.set_yticklabels(custom_y_ticks_labels)
plt.grid(axis='both',color='grey')
plt.xlim(0.0,1.0)
# Out:
# /var/folders/88/94pqx5n57z5crmg3w50s99y00000gn/T/ipykernel_13286/3848255400.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(custom_y_ticks_labels)
# (0.0, 1.0)

# %% [markdown]
# # China Quali

# %%
china_quali = fastf1.get_session(2025,'China','Qualifying')
china_quali.load()
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Qualifying [v3.5.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# /opt/anaconda3/envs/python_ads_new/lib/python3.9/site-packages/fastf1/core.py:1610: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['81', '63', '4', '1', '44', '16', '6', '12', '22', '23', '31', '27', '14', '18', '55', '10', '87', '7', '5', '30']

# %%
q_df = china_quali.laps

# %%
fastest_laps = []
for driver in drivers:
    fastest_lap_dr = q_df.pick_drivers(driver).pick_fastest()
    fastest_laps.append(fastest_lap_dr)

fastest_laps = Laps(fastest_laps)

# %%
pole_lap = fastest_laps.pick_fastest()
fastest_laps['LapTimeDelta'] = fastest_laps['LapTime'] - pole_lap['LapTime']
fastest_laps['Delta in seconds'] = fastest_laps['LapTimeDelta'].dt.total_seconds()
fastest_laps.sort_values('Delta in seconds',inplace=True)

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(orient='horizontal',data=fastest_laps.head(10),x='Delta in seconds',y='Driver',hue='Driver',palette=driver_colors)
plt.title('Delta from Pole Position - Qualifying')
plt.ylabel('Driver')
plt.xlabel('Delta [s]')
plt.xticks(np.arange(fastest_laps['Delta in seconds'].min(),fastest_laps['Delta in seconds'].max(),0.1))
custom_y_ticks_labels = [f'{team} {drv}' for team, drv, in zip(fastest_laps['Team'],fastest_laps['Driver'])]
ax.set_yticklabels(custom_y_ticks_labels)
plt.grid(axis='both',color='grey')
plt.xlim(0.0,1.0)
# Out:
# /var/folders/88/94pqx5n57z5crmg3w50s99y00000gn/T/ipykernel_13286/960815932.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(custom_y_ticks_labels)
# (0.0, 1.0)
